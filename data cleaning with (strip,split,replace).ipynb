# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Microsoft\Downloads\Titanic-Dataset.csv")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.Name.str.upper()
# Out:
# 0                                BRAUND, MR. OWEN HARRIS
# 1      CUMINGS, MRS. JOHN BRADLEY (FLORENCE BRIGGS TH...
# 2                                 HEIKKINEN, MISS. LAINA
# 3           FUTRELLE, MRS. JACQUES HEATH (LILY MAY PEEL)
# 4                               ALLEN, MR. WILLIAM HENRY
#                              ...
# 886                                MONTVILA, REV. JUOZAS
# 887                         GRAHAM, MISS. MARGARET EDITH
# 888             JOHNSTON, MISS. CATHERINE HELEN "CARRIE"
# 889                                BEHR, MR. KARL HOWELL
# 890                                  DOOLEY, MR. PATRICK
# Name: Name, Length: 891, dtype: object

# %%
df.Name.str.lower()
# Out:
# 0                                braund, mr. owen harris
# 1      cumings, mrs. john bradley (florence briggs th...
# 2                                 heikkinen, miss. laina
# 3           futrelle, mrs. jacques heath (lily may peel)
# 4                               allen, mr. william henry
#                              ...
# 886                                montvila, rev. juozas
# 887                         graham, miss. margaret edith
# 888             johnston, miss. catherine helen "carrie"
# 889                                behr, mr. karl howell
# 890                                  dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df.Name.str.capitalize()
# Out:
# 0                                Braund, mr. owen harris
# 1      Cumings, mrs. john bradley (florence briggs th...
# 2                                 Heikkinen, miss. laina
# 3           Futrelle, mrs. jacques heath (lily may peel)
# 4                               Allen, mr. william henry
#                              ...
# 886                                Montvila, rev. juozas
# 887                         Graham, miss. margaret edith
# 888             Johnston, miss. catherine helen "carrie"
# 889                                Behr, mr. karl howell
# 890                                  Dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df.Name.head()
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# Name: Name, dtype: object

# %%
df.lower_name=df.Name.str.lower()
# Out:
# C:\Users\Microsoft\AppData\Local\Temp\ipykernel_9356\782260990.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.lower_name=df.Name.str.lower()

# %%
df.lower_name.str.capitalize()
# Out:
# 0                                Braund, mr. owen harris
# 1      Cumings, mrs. john bradley (florence briggs th...
# 2                                 Heikkinen, miss. laina
# 3           Futrelle, mrs. jacques heath (lily may peel)
# 4                               Allen, mr. william henry
#                              ...
# 886                                Montvila, rev. juozas
# 887                         Graham, miss. margaret edith
# 888             Johnston, miss. catherine helen "carrie"
# 889                                Behr, mr. karl howell
# 890                                  Dooley, mr. patrick
# Name: Name, Length: 891, dtype: object

# %%
df.kabin=df.Cabin.str[0]
# Out:
# C:\Users\Microsoft\AppData\Local\Temp\ipykernel_9356\78782589.py:1: UserWarning: Pandas doesn't allow columns to be created via a new attribute name - see https://pandas.pydata.org/pandas-docs/stable/indexing.html#attribute-access
#   df.kabin=df.Cabin.str[0]

# %%
df.kabin=df.kabin.replace("C","k",regex=True)

# %%
df.kabin
# Out:
# 0      NaN
# 1        k
# 2      NaN
# 3        k
# 4      NaN
#       ...
# 886    NaN
# 887      B
# 888    NaN
# 889      k
# 890    NaN
# Name: Cabin, Length: 891, dtype: object

# %%
df.groupby("kabin").Survived.mean()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 1
# ----> 1 df.groupby("kabin").Survived.mean()
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# ...

# %%
df.groupby("kabin")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 df.groupby("kabin")
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:8252, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8249     raise TypeError("You have to supply one of 'by' and 'level'")
#    8250 axis = self._get_axis_number(axis)
# -> 8252 return DataFrameGroupBy(
#    8253     obj=self,
#    8254     keys=by,
#    8255     axis=axis,
#    8256     level=level,
#    8257     as_index=as_index,
#    8258     sort=sort,
#    8259     group_keys=group_keys,
#    8260     observed=observed,
#    8261     dropna=dropna,
#    8262 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:931, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
# ...

# %%
df["kabin"]=df["Cabin"].str[0]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df.groupby("kabin")["Survived"].mean()
# Out:
# kabin
# A    0.466667
# B    0.744681
# C    0.593220
# D    0.757576
# E    0.750000
# F    0.615385
# G    0.500000
# T    0.000000
# Name: Survived, dtype: float64

# %%
df.groupby("kabin")["Survived"].mean().sort_values().plot(kind="bar",title="mean of Survived",color="Red",xlabel="sahar",ylabel="tara")
# Out:
# <Axes: title={'center': 'mean of Survived'}, xlabel='sahar', ylabel='tara'>

# %%
df.Cabin.str[0:3]
# Out:
# 0      NaN
# 1      C85
# 2      NaN
# 3      C12
# 4      NaN
#       ...
# 886    NaN
# 887    B42
# 888    NaN
# 889    C14
# 890    NaN
# Name: Cabin, Length: 891, dtype: object

# %%
s=pd.Series(['1. hawk.  ','2. prckle \t','3. hfhf \t ??\n'])

# %%
s
# Out:
# 0         1. hawk.
# 1       2. prckle \t
# 2    3. hfhf \t ??\n
# dtype: object

# %%
s.str.strip()
# Out:
# 0       1. hawk.
# 1      2. prckle
# 2    3. hfhf\t??
# dtype: object

# %%
s.str.rstrip()
# Out:
# 0       1. hawk.
# 1      2. prckle
# 2    3. hfhf\t??
# dtype: object

# %%
s.str.lstrip(to_strip='1 .')
# Out:
# 0            hawk.
# 1       2. prckle \t
# 2    3. hfhf \t ??\n
# dtype: object

# %%
s.str.lstrip(to_strip='123.')
# Out:
# 0        hawk.
# 1      prckle \t
# 2     hfhf\t??\n
# dtype: object

# %%
s.str.strip(to_strip='123.h \n \t ?')
# Out:
# 0       awk
# 1    prckle
# 2       fhf
# dtype: object

# %%
s.str.split("?",expand=True )
# Out:
#               0     1     2
# 0    1. hawk.    None  None
# 1  2. prckle \t  None  None
# 2   3. hfhf \t           \n

# %%
s.str.split("?",n=1  ,expand=True )
# Out:
#               0     1
# 0    1. hawk.    None
# 1  2. prckle \t  None
# 2   3. hfhf \t    ?\n

# %%
s.str.split("?",expand=True ,n=1   )
# Out:
#               0     1
# 0    1. hawk.    None
# 1  2. prckle \t  None
# 2   3. hfhf \t    ?\n

# %%
s.str.rsplit("?",expand=True ,n=1 )
# Out:
#               0     1
# 0    1. hawk.    None
# 1  2. prckle \t  None
# 2  3. hfhf \t ?    \n

# %%
s.str.split("?",expand=True )
# Out:
#               0     1     2
# 0    1. hawk.    None  None
# 1  2. prckle \t  None  None
# 2   3. hfhf \t           \n

# %%
s["name"]=s.str.split("?",expand=True )[0]

# %%
print(s)
# Out:
# 0                                              1. hawk.
# 1                                            2. prckle \t
# 2                                         3. hfhf \t ??\n
# name    0      1. hawk.
# 1    2. prckle \t
# 2     3. h...
# dtype: object

# %%
s["name"]
# Out:
# 0      1. hawk.
# 1    2. prckle \t
# 2     3. hfhf \t
# Name: 0, dtype: object

# %%
s.str.split("?",expand=True )
# Out:
#                  0     1     2
# 0       1. hawk.    None  None
# 1     2. prckle \t  None  None
# 2      3. hfhf \t           \n
# name           NaN   NaN   NaN

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["part1"]=df["Name"].str.split(",",expand=True,n=1)[0]

df["part2"]=df["Name"].str.split(",",expand=True,n=1)[1]

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["Name"].str.split(",",expand=True,n=1)
# Out:
#              0                                            1
# 0       Braund                              Mr. Owen Harris
# 1      Cumings   Mrs. John Bradley (Florence Briggs Thayer)
# 2    Heikkinen                                  Miss. Laina
# 3     Futrelle           Mrs. Jacques Heath (Lily May Peel)
# 4        Allen                            Mr. William Henry
# ..         ...                                          ...
# 886   Montvila                                  Rev. Juozas
# 887     Graham                         Miss. Margaret Edith
# 888   Johnston               Miss. Catherine Helen "Carrie"
# 889       Behr                              Mr. Karl Howell
# 890     Dooley                                  Mr. Patrick
#
# [891 rows x 2 columns]

# %%
df["Name"].str.split(",",expand=False,n=1)
# Out:
# 0                             [Braund,  Mr. Owen Harris]
# 1      [Cumings,  Mrs. John Bradley (Florence Briggs ...
# 2                              [Heikkinen,  Miss. Laina]
# 3        [Futrelle,  Mrs. Jacques Heath (Lily May Peel)]
# 4                            [Allen,  Mr. William Henry]
#                              ...
# 886                             [Montvila,  Rev. Juozas]
# 887                      [Graham,  Miss. Margaret Edith]
# 888          [Johnston,  Miss. Catherine Helen "Carrie"]
# 889                             [Behr,  Mr. Karl Howell]
# 890                               [Dooley,  Mr. Patrick]
# Name: Name, Length: 891, dtype: object

# %%
df["female"]=df.Sex.str.replace("female","F")

# %%
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df["female"].str.replace("male","M")
# Out:
# 0      M
# 1      F
# 2      F
# 3      F
# 4      M
#       ..
# 886    M
# 887    F
# 888    F
# 889    M
# 890    M
# Name: female, Length: 891, dtype: object

# %%
def a(ros):
    return ros.group()[0]

# %%
df["Sex"].str.replace("female|male",a,regex=True )
# Out:
# 0      m
# 1      f
# 2      f
# 3      f
# 4      m
#       ..
# 886    m
# 887    f
# 888    f
# 889    m
# 890    m
# Name: Sex, Length: 891, dtype: object

# %%
df["Sex"].replace(["female","male"],["F","M"] )
# Out:
# 0      M
# 1      F
# 2      F
# 3      F
# 4      M
#       ..
# 886    M
# 887    F
# 888    F
# 889    M
# 890    M
# Name: Sex, Length: 891, dtype: object
