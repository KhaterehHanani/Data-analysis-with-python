# %% [markdown]
# seanorb library
# **********************
# relplot(relational)
# 1.scatterplot
# 2.lineplot
#
# *********************
# displot(distributions)
# 1.histplot
# 2.kdeplot
# 3.rugplot
# 4.ecdfplot
# *********************
# catplot(categorical)
# 1.stripplot
# 2.swarmplot
# 3.boxplot
# 4.violinplot
# 5.pointplot
# 6.barplot

# %%
import seaborn as sns
t=sns.load_dataset('tips')
f=sns.load_dataset('flights')
p=sns.load_dataset('penguins')

tax=sns.load_dataset('taxis')#parse_dates=["pickup","dropoff"])
tax.info()
tax["hourpic"]=tax["pickup"].dt.hour
tax["hourdrop"]=tax["dropoff"].dt.hour
tax["droptime"]=tax["dropoff"].dt.time
tax
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6433 entries, 0 to 6432
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   pickup           6433 non-null   datetime64[ns]
#  1   dropoff          6433 non-null   datetime64[ns]
#  2   passengers       6433 non-null   int64
#  3   distance         6433 non-null   float64
#  4   fare             6433 non-null   float64
#  5   tip              6433 non-null   float64
#  6   tolls            6433 non-null   float64
#  7   total            6433 non-null   float64
#  8   color            6433 non-null   object
#  9   payment          6389 non-null   object
#  10  pickup_zone      6407 non-null   object
#  11  dropoff_zone     6388 non-null   object
#  12  pickup_borough   6407 non-null   object
#  13  dropoff_borough  6388 non-null   object
# dtypes: datetime64[ns](2), float64(5), int64(1), object(6)
# memory usage: 703.7+ KB
# ...

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
seaborn.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
sns.scatterplot(data=t ,x="total_bill", y="tip")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=t ,x="total_bill", y="tip" ,hue="smoker")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.scatterplot(data=t ,x="total_bill", y="tip" ,hue="smoker" ,style="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.set_theme()
sns.scatterplot(data=t ,x="total_bill", y="tip" ,hue="smoker" ,style="time")
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %%
sns.lineplot(data=f ,x="year", y="passengers",ci=None)
# Out:
# C:\Users\Microsoft\AppData\Local\Temp\ipykernel_9636\1727382752.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.lineplot(data=f ,x="year", y="passengers",ci=None)
# <Axes: xlabel='year', ylabel='passengers'>

# %%
f
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
sns.lineplot(data=f ,x="year", y="passengers",estimator='max',ci=100)
# Out:
# C:\Users\Microsoft\AppData\Local\Temp\ipykernel_9636\1904569595.py:1: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 100)` for the same effect.
#
#   sns.lineplot(data=f ,x="year", y="passengers",estimator='max',ci=100)
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=f ,x="year", y="passengers",estimator='sum')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.scatterplot(data=f ,x="year", y="passengers")
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=f ,x="year", y="passengers",estimator='sum')
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
sns.lineplot(data=f ,x="year", y="passengers",estimator='sum')
f.groupby('year')["passengers"].sum().plot()
# Out:
# <Axes: xlabel='year', ylabel='passengers'>

# %%
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tax
# Out:
#                   pickup             dropoff  passengers  distance  fare  \
# 0    2019-03-23 20:21:09 2019-03-23 20:27:24           1      1.60   7.0
# 1    2019-03-04 16:11:55 2019-03-04 16:19:00           1      0.79   5.0
# 2    2019-03-27 17:53:01 2019-03-27 18:00:25           1      1.37   7.5
# 3    2019-03-10 01:23:59 2019-03-10 01:49:51           1      7.70  27.0
# 4    2019-03-30 13:27:42 2019-03-30 13:37:14           3      2.16   9.0
# ...                  ...                 ...         ...       ...   ...
# 6428 2019-03-31 09:51:53 2019-03-31 09:55:27           1      0.75   4.5
# 6429 2019-03-31 17:38:00 2019-03-31 18:34:23           1     18.74  58.0
# 6430 2019-03-23 22:55:18 2019-03-23 23:14:25           1      4.14  16.0
# 6431 2019-03-04 10:09:25 2019-03-04 10:14:29           1      1.12   6.0
# 6432 2019-03-13 19:31:22 2019-03-13 19:48:02           1      3.85  15.0
#
#        tip  tolls  total   color      payment            pickup_zone  \
# ...

# %%
sns.lineplot(data=tax ,x="hourpic", y="total",hue="payment")
# Out:
# <Axes: xlabel='hourpic', ylabel='total'>

# %%
sns.lineplot(data=tax ,x="hourpic", y="total",hue="payment",style="color")
# Out:
# <Axes: xlabel='hourpic', ylabel='total'>

# %%
sns.relplot(data=tax ,x="hourpic", y="total",hue="payment")
# Out:
# C:\Users\Microsoft\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data=tax ,x="hourpic", y="total",hue="payment",kind="line")
# Out:
# C:\Users\Microsoft\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data=tax ,x="hourpic", y="total",hue="payment",kind="line",col="color")
# Out:
# C:\Users\Microsoft\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data=tax ,x="hourpic", y="total",row="payment",kind="line",col="color")
# Out:
# C:\Users\Microsoft\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.relplot(data=t ,x="total_bill", y="tip",row="time",kind="scatter",col="sex")
# Out:
# C:\Users\Microsoft\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.relplot(data=t ,x="total_bill", y="tip",row="time",kind="scatter",col="sex", hue="smoker")
# Out:
# C:\Users\Microsoft\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.set_theme()
sns.relplot(data=t ,x="total_bill", y="tip",row="time",kind="scatter",col="sex", hue="smoker")
# Out:
# C:\Users\Microsoft\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
t
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
sns.histplot(data=t ,x="tip"  ,hue="time" )
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=t ,x="tip"  ,hue="time" ,multiple="dodge")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=t ,x="tip"  ,hue="time" ,multiple="stack")
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=t ,x="tip"  ,hue="time" ,multiple="dodge" , bins=5)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=t ,x="tip"  ,hue="time" ,multiple="stack", bins=5)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=t ,x="tip"  ,hue="time" ,multiple="stack" ,  binwidth=2)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
sns.histplot(data=t ,x="tip"  ,hue="time" ,multiple="dodge" , bins=5 ,kde= True)
# Out:
# <Axes: xlabel='tip', ylabel='Count'>

# %%
p
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.kdeplot(data=p , x="body_mass_g" ,hue="species" )
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=p , x="body_mass_g" ,hue="species" ,bw_adjust=1)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=p , x="body_mass_g" ,hue="species" ,bw_adjust=0.2)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=p , x="body_mass_g" ,hue="species" ,bw_adjust=0.4)
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=p , x="body_mass_g" ,hue="species" ,bw_adjust=0.4 ,multiple ="stack")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
sns.kdeplot(data=p , x="body_mass_g" ,hue="species" ,bw_adjust=0.4 ,multiple ="layer")
# Out:
# <Axes: xlabel='body_mass_g', ylabel='Density'>

# %%
p
# Out:
#     species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0    Adelie  Torgersen            39.1           18.7              181.0
# 1    Adelie  Torgersen            39.5           17.4              186.0
# 2    Adelie  Torgersen            40.3           18.0              195.0
# 3    Adelie  Torgersen             NaN            NaN                NaN
# 4    Adelie  Torgersen            36.7           19.3              193.0
# ..      ...        ...             ...            ...                ...
# 339  Gentoo     Biscoe             NaN            NaN                NaN
# 340  Gentoo     Biscoe            46.8           14.3              215.0
# 341  Gentoo     Biscoe            50.4           15.7              222.0
# 342  Gentoo     Biscoe            45.2           14.8              212.0
# 343  Gentoo     Biscoe            49.9           16.1              213.0
#
#      body_mass_g     sex
# 0         3750.0    Male
# 1         3800.0  Female
# ...

# %%
sns.kdeplot(data=p , x="bill_length_mm" , y= "flipper_length_mm"  ,   hue="species" ,bw_adjust=0.4 ,multiple ="stack")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.histplot(data=p , x="bill_length_mm" , y= "flipper_length_mm"  )
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.histplot(data=p , x="bill_length_mm" , y= "flipper_length_mm"  ,hue="species")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.rugplot(data=p , x="bill_length_mm")
# Out:
# <Axes: xlabel='bill_length_mm'>

# %%
sns.rugplot(data=p , x="bill_length_mm" ,height=0.5)
# Out:
# <Axes: xlabel='bill_length_mm'>

# %%
sns.rugplot(data=p , x="bill_length_mm" ,height=0.5 , y= "flipper_length_mm" )# ,hue="species")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.rugplot(data=p , x="bill_length_mm"  , y= "flipper_length_mm"  ,height=0.5,hue="species")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.kdeplot(data=p , x="bill_length_mm" , y= "flipper_length_mm"  ,   hue="species")# ,bw_adjust=0.4 ,multiple ="stack")
sns.rugplot(data=p , x="bill_length_mm" ,height=0.5 , y= "flipper_length_mm"  ,hue="species")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.rugplot(data=p , x="bill_length_mm" ,height=0.5 , y= "flipper_length_mm"  ,hue="species")
sns.kdeplot(data=p , x="bill_length_mm" , y= "flipper_length_mm"  ,   hue="species")# ,bw_adjust=0.4 ,multiple ="stack")
# Out:
# <Axes: xlabel='bill_length_mm', ylabel='flipper_length_mm'>

# %%
sns.displot(data=p , x="bill_length_mm" ,kind="hist")
# Out:
# C:\Users\Microsoft\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=p , x="bill_length_mm" ,kind="kde")
# Out:
# C:\Users\Microsoft\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=p , x="bill_length_mm" ,kind= "kde" , rug=True,height=3 ,aspect=0.5)
# Out:
# C:\Users\Microsoft\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=p , x="bill_length_mm" ,kind= "kde" , rug=True,height=3 ,aspect=2)
# Out:
# C:\Users\Microsoft\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=p , x="bill_length_mm" ,kind= "kde" , rug=True,height=3 ,aspect=2 , col="species")
# Out:
# C:\Users\Microsoft\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.displot(data=p , x="bill_length_mm" ,kind= "kde" , rug=True,height=3 ,aspect=2 , col="species" , hue="sex")
# Out:
# C:\Users\Microsoft\anaconda3\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
