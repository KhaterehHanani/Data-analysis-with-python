# %%
import pandas as pd
df=pd.read_csv(r"C:\Users\Microsoft\Downloads\data\DataAnalysisCourseMaterials\DataAnalysis\data\state_pops.csv")
dft=pd.read_csv(r"C:\Users\Microsoft\Downloads\data\DataAnalysisCourseMaterials\DataAnalysis\data\titanic.csv")

# %%
df
# Out:
#      state  year   population
# 0       AL  2012    4817528.0
# 1       AL  2010    4785570.0
# 2       AL  2011    4801627.0
# 3       AL  2009    4757938.0
# 4       AL  2013    4833722.0
# ...    ...   ...          ...
# 1267   USA  2013  316128839.0
# 1268   USA  2009  306771529.0
# 1269   USA  2010  309326295.0
# 1270   USA  2011  311582564.0
# 1271   USA  2012  313873685.0
#
# [1272 rows x 3 columns]

# %%
df2=df.groupby(['state','year'])

# %%
df2

# %%
df2.min('population')
# Out:
#             population
# state year
# AK    1990    553290.0
#       1991    570193.0
#       1992    588736.0
#       1993    599434.0
#       1994    603308.0
# ...                ...
# WY    2009    559851.0
#       2010    564222.0
#       2011    567329.0
#       2012    576626.0
#       2013    582658.0
#
# [1272 rows x 1 columns]

# %%
dft
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex     age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...

# %%
df3=dft.groupby(['sex','age'])

# %%
df3

# %%
df3["survived"].mean()
# Out:
# sex     age
# female  0.1667    1.000000
#         0.75      1.000000
#         0.9167    1.000000
#         1         0.800000
#         10        0.000000
#                     ...
# male    74        0.000000
#         8         0.666667
#         80        1.000000
#         9         0.600000
#         ?         0.140541
# Name: survived, Length: 168, dtype: float64

# %%
print(dft.index)
# Out:
# RangeIndex(start=0, stop=1309, step=1)

# %%
df3["survived"].mean().index
# Out:
# MultiIndex([('female', '0.1667'),
#             ('female',   '0.75'),
#             ('female', '0.9167'),
#             ('female',      '1'),
#             ('female',     '10'),
#             ('female',     '11'),
#             ('female',     '12'),
#             ('female',     '13'),
#             ('female',     '14'),
#             ('female',   '14.5'),
#             ...
#             (  'male',     '67'),
#             (  'male',      '7'),
#             (  'male',     '70'),
#             (  'male',   '70.5'),
#             (  'male',     '71'),
#             (  'male',     '74'),
#             (  'male',      '8'),
#             (  'male',     '80'),
#             (  'male',      '9'),
#             (  'male',      '?')],
#            names=['sex', 'age'], length=168)

# %%
dft1=dft.set_index("name")

# %%
dft1.index
# Out:
# Index(['Allen, Miss. Elisabeth Walton', 'Allison, Master. Hudson Trevor',
#        'Allison, Miss. Helen Loraine', 'Allison, Mr. Hudson Joshua Creighton',
#        'Allison, Mrs. Hudson J C (Bessie Waldo Daniels)',
#        'Anderson, Mr. Harry', 'Andrews, Miss. Kornelia Theodosia',
#        'Andrews, Mr. Thomas Jr',
#        'Appleton, Mrs. Edward Dale (Charlotte Lamson)',
#        'Artagaveytia, Mr. Ramon',
#        ...
#        'Yasbeck, Mr. Antoni', 'Yasbeck, Mrs. Antoni (Selini Alexander)',
#        'Youseff, Mr. Gerious', 'Yousif, Mr. Wazli', 'Yousseff, Mr. Gerious',
#        'Zabour, Miss. Hileni', 'Zabour, Miss. Thamine',
#        'Zakarian, Mr. Mapriededer', 'Zakarian, Mr. Ortin',
#        'Zimmerman, Mr. Leo'],
#       dtype='object', name='name', length=1309)

# %%
dft2=dft.set_index("cabin")

# %%
dft2.index
# Out:
# Index(['B5', 'C22 C26', 'C22 C26', 'C22 C26', 'C22 C26', 'E12', 'D7', 'A36',
#        'C101', '?',
#        ...
#        '?', '?', '?', '?', '?', '?', '?', '?', '?', '?'],
#       dtype='object', name='cabin', length=1309)

# %%
dft2.loc["?"]
# Out:
#        pclass  survived                          name     sex   age  sibsp  \
# cabin
# ?           1         0       Artagaveytia, Mr. Ramon    male    71      0
# ?           1         1  Barber, Miss. Ellen 'Nellie'  female    26      0
# ?           1         0           Baumann, Mr. John D    male     ?      0
# ?           1         1         Bidois, Miss. Rosalie  female    42      0
# ?           1         0           Birnbaum, Mr. Jakob    male    25      0
# ...       ...       ...                           ...     ...   ...    ...
# ?           3         0          Zabour, Miss. Hileni  female  14.5      1
# ?           3         0         Zabour, Miss. Thamine  female     ?      1
# ?           3         0     Zakarian, Mr. Mapriededer    male  26.5      0
# ?           3         0           Zakarian, Mr. Ortin    male    27      0
# ?           3         0            Zimmerman, Mr. Leo    male    29      0
#
# ...

# %%
dfdouble=dft.set_index(["sex","age"])

# %%
dfdouble.index
# Out:
# MultiIndex([('female',     '29'),
#             (  'male', '0.9167'),
#             ('female',      '2'),
#             (  'male',     '30'),
#             ('female',     '25'),
#             (  'male',     '48'),
#             ('female',     '63'),
#             (  'male',     '39'),
#             ('female',     '53'),
#             (  'male',     '71'),
#             ...
#             (  'male',     '27'),
#             ('female',     '15'),
#             (  'male',   '45.5'),
#             (  'male',      '?'),
#             (  'male',      '?'),
#             ('female',   '14.5'),
#             ('female',      '?'),
#             (  'male',   '26.5'),
#             (  'male',     '27'),
#             (  'male',     '29')],
#            names=['sex', 'age'], length=1309)

# %%
dfdouble.loc["male"]
# Out:
#         pclass  survived                                  name  sibsp  parch  \
# age
# 0.9167       1         1        Allison, Master. Hudson Trevor      1      2
# 30           1         0  Allison, Mr. Hudson Joshua Creighton      1      2
# 48           1         1                   Anderson, Mr. Harry      0      0
# 39           1         0                Andrews, Mr. Thomas Jr      0      0
# 71           1         0               Artagaveytia, Mr. Ramon      0      0
# ...        ...       ...                                   ...    ...    ...
# ?            3         0                     Yousif, Mr. Wazli      0      0
# ?            3         0                 Yousseff, Mr. Gerious      0      0
# 26.5         3         0             Zakarian, Mr. Mapriededer      0      0
# 27           3         0                   Zakarian, Mr. Ortin      0      0
# 29           3         0                    Zimmerman, Mr. Leo      0      0
#
# ...

# %%
dfdouble.loc["male","30"]
# Out:
# C:\Users\Microsoft\AppData\Local\Temp\ipykernel_14756\2510255193.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   dfdouble.loc["male","30"]
#           pclass  survived                                    name  sibsp  \
# sex  age
# male 30        1         0    Allison, Mr. Hudson Joshua Creighton      1
#      30        1         0         Foreman, Mr. Benjamin Laventall      0
#      30        1         0              Loring, Mr. Joseph Holland      0
#      30        1         0                Maguire, Mr. John Edward      0
#      30        1         1                Mock, Mr. Philipp Edmund      1
#      30        2         0                     Abelson, Mr. Samuel      1
#      30        2         0          Aldworth, Mr. Charles Augustus      0
#      30        2         0             Givard, Mr. Hans Kristensen      0
#      30        2         0                      Hale, Mr. Reginald      0
# ...

# %%
dfdouble.loc[:,"30",:]
# Out:
#         pclass  survived                                               name  \
# sex
# male         1         0               Allison, Mr. Hudson Joshua Creighton
# female       1         1                            Bonnell, Miss. Caroline
# female       1         1                               Cherry, Miss. Gladys
# male         1         0                    Foreman, Mr. Benjamin Laventall
# female       1         1                     Francatelli, Miss. Laura Mabel
# female       1         1                                LeRoy, Miss. Bertha
# male         1         0                         Loring, Mr. Joseph Holland
# male         1         0                           Maguire, Mr. John Edward
# male         1         1                           Mock, Mr. Philipp Edmund
# female       1         1                              Perreault, Miss. Anne
# female       1         1                            Serepeca, Miss. Augusta
# ...

# %%
dfdouble.loc[:,['30','35'],:]
# Out:
#             pclass  survived                                  name  sibsp  \
# sex    age
# male   30        1         0  Allison, Mr. Hudson Joshua Creighton      1
# female 30        1         1               Bonnell, Miss. Caroline      0
#        30        1         1                  Cherry, Miss. Gladys      0
# male   30        1         0       Foreman, Mr. Benjamin Laventall      0
# female 30        1         1        Francatelli, Miss. Laura Mabel      0
# ...            ...       ...                                   ...    ...
# male   35        3         0       Brocklebank, Mr. William Alfred      0
#        35        3         0                       Cor, Mr. Bartol      0
#        35        3         0                    Markoff, Mr. Marin      0
# female 35        3         0              McGowan, Miss. Katherine      0
# male   35        3         0                  Rintamaki, Mr. Matti      0
#
# ...

# %%
dfdouble.loc['male','30']
# Out:
# C:\Users\Microsoft\AppData\Local\Temp\ipykernel_14756\320155157.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   dfdouble.loc['male','30']
#           pclass  survived                                    name  sibsp  \
# sex  age
# male 30        1         0    Allison, Mr. Hudson Joshua Creighton      1
#      30        1         0         Foreman, Mr. Benjamin Laventall      0
#      30        1         0              Loring, Mr. Joseph Holland      0
#      30        1         0                Maguire, Mr. John Edward      0
#      30        1         1                Mock, Mr. Philipp Edmund      1
#      30        2         0                     Abelson, Mr. Samuel      1
#      30        2         0          Aldworth, Mr. Charles Augustus      0
#      30        2         0             Givard, Mr. Hans Kristensen      0
#      30        2         0                      Hale, Mr. Reginald      0
# ...

# %%
dfdouble.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1309 entries, ('female', '29') to ('male', '29')
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sibsp      1309 non-null   int64
#  4   parch      1309 non-null   int64
#  5   ticket     1309 non-null   object
#  6   fare       1309 non-null   object
#  7   cabin      1309 non-null   object
#  8   embarked   1309 non-null   object
#  9   boat       1309 non-null   object
#  10  body       1309 non-null   object
#  11  home.dest  1309 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 160.6+ KB

# %%
dfdouble.loc['male','35']
# Out:
# C:\Users\Microsoft\AppData\Local\Temp\ipykernel_14756\1061772325.py:1: PerformanceWarning: indexing past lexsort depth may impact performance.
#   dfdouble.loc['male','35']
#           pclass  survived                              name  sibsp  parch  \
# sex  age
# male 35        1         1   Homer, Mr. Harry ('Mr E Haven')      0      0
#      35        1         1            Lesurer, Mr. Gustave J      0      0
#      35        1         1  Silverthorne, Mr. Spencer Victor      0      0
#      35        2         0              Fynney, Mr. Joseph J      0      0
#      35        2         0                 Keane, Mr. Daniel      0      0
#      35        2         0         Slemen, Mr. Richard James      0      0
#      35        3         0          Allen, Mr. William Henry      0      0
#      35        3         0                   Asim, Mr. Adola      0      0
#      35        3         0   Brocklebank, Mr. William Alfred      0      0
# ...

# %%
dfsingle=dft.set_index("age")

# %%
dfsingle
# Out:
#         pclass  survived                                             name  \
# age
# 29           1         1                    Allen, Miss. Elisabeth Walton
# 0.9167       1         1                   Allison, Master. Hudson Trevor
# 2            1         0                     Allison, Miss. Helen Loraine
# 30           1         0             Allison, Mr. Hudson Joshua Creighton
# 25           1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...        ...       ...                                              ...
# 14.5         3         0                             Zabour, Miss. Hileni
# ?            3         0                            Zabour, Miss. Thamine
# 26.5         3         0                        Zakarian, Mr. Mapriededer
# 27           3         0                              Zakarian, Mr. Ortin
# 29           3         0                               Zimmerman, Mr. Leo
#
# ...

# %%
dfsingle.loc['30']
# Out:
#      pclass  survived                                               name  \
# age
# 30        1         0               Allison, Mr. Hudson Joshua Creighton
# 30        1         1                            Bonnell, Miss. Caroline
# 30        1         1                               Cherry, Miss. Gladys
# 30        1         0                    Foreman, Mr. Benjamin Laventall
# 30        1         1                     Francatelli, Miss. Laura Mabel
# 30        1         1                                LeRoy, Miss. Bertha
# 30        1         0                         Loring, Mr. Joseph Holland
# 30        1         0                           Maguire, Mr. John Edward
# 30        1         1                           Mock, Mr. Philipp Edmund
# 30        1         1                              Perreault, Miss. Anne
# 30        1         1                            Serepeca, Miss. Augusta
# 30        2         0                                Abelson, Mr. Samuel
# ...

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1309 non-null   object
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: int64(4), object(10)
# memory usage: 143.3+ KB

# %%
dft.age=dft.age.replace('?',None).astype(float)

# %%
dft.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1309 non-null   object
#  9   cabin      1309 non-null   object
#  10  embarked   1309 non-null   object
#  11  boat       1309 non-null   object
#  12  body       1309 non-null   object
#  13  home.dest  1309 non-null   object
# dtypes: float64(1), int64(4), object(9)
# memory usage: 143.3+ KB

# %%
dfsingle=dft.set_index("age")

# %%
dfsingle.sort_index(inplace=True)
dfsingle
#dfsingle.loc[[30:36]]
# Out:
#         pclass  survived                                     name     sex  \
# age
# 0.1667       3         1  Dean, Miss. Elizabeth Gladys 'Millvina'  female
# 0.3333       3         0  Danbom, Master. Gilbert Sigvard Emanuel    male
# 0.4167       3         1          Thomas, Master. Assad Alexander    male
# 0.6667       2         1                Hamalainen, Master. Viljo    male
# 0.7500       3         0           Peacock, Master. Alfred Edward    male
# ...        ...       ...                                      ...     ...
# NaN          3         0        Williams, Mr. Howard Hugh 'Harry'    male
# NaN          3         0                   Wiseman, Mr. Phillippe    male
# NaN          3         0                        Yousif, Mr. Wazli    male
# NaN          3         0                    Yousseff, Mr. Gerious    male
# NaN          3         0                    Zabour, Miss. Thamine  female
#
# ...

# %%
dfsingle.loc[30:36]
# Out:
#       pclass  survived                                               name  \
# age
# 30.0       1         0                         Loring, Mr. Joseph Holland
# 30.0       3         0                           Lobb, Mr. William Arthur
# 30.0       3         0  Lindell, Mrs. Edvard Bengtsson (Elin Gerda Per...
# 30.0       2         0                        Givard, Mr. Hans Kristensen
# 30.0       1         1                              Perreault, Miss. Anne
# ...      ...       ...                                                ...
# 36.0       1         1                           Young, Miss. Marie Grice
# 36.0       2         1  Angle, Mrs. William A (Florence 'Mary' Agnes H...
# 36.0       1         1                            Crosby, Miss. Harriet R
# 36.0       3         0                        Van Impe, Mr. Jean Baptiste
# 36.0       3         0                          Wittevrongel, Mr. Camille
#
# ...

# %%
dfdouble.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 1309 entries, ('female', '29') to ('male', '29')
# Data columns (total 12 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sibsp      1309 non-null   int64
#  4   parch      1309 non-null   int64
#  5   ticket     1309 non-null   object
#  6   fare       1309 non-null   object
#  7   cabin      1309 non-null   object
#  8   embarked   1309 non-null   object
#  9   boat       1309 non-null   object
#  10  body       1309 non-null   object
#  11  home.dest  1309 non-null   object
# dtypes: int64(4), object(8)
# memory usage: 160.6+ KB

# %%
dfdouble.sort_index(inplace=True)

# %%
dfdouble.loc[('female','30'):('female','35')]
# Out:
#              pclass  survived  \
# sex    age
# female 30         1         1
#        30         1         1
#        30         1         1
#        30         1         1
#        30         1         1
#        30         1         1
#        30         2         0
#        30         2         1
#        30         2         1
#        30         2         1
#        30         2         1
#        30         3         0
#        30         3         0
#        30         3         1
#        30         3         1
#        30         3         0
#        30         3         0
#        30.5       3         0
#        31         1         1
#        31         1         1
#        31         1         1
#        31         2         1
#        31         2         1
#        31         2         1
#        31         3         1
#        31         3         0
#        31         3         1
#        31         3         0
#        32         1         1
# ...

# %%
dfdouble.loc[('female','30'):('male','35')]
# Out:
#             pclass  survived                             name  sibsp  parch  \
# sex    age
# female 30        1         1          Bonnell, Miss. Caroline      0      0
#        30        1         1             Cherry, Miss. Gladys      0      0
#        30        1         1   Francatelli, Miss. Laura Mabel      0      0
#        30        1         1              LeRoy, Miss. Bertha      0      0
#        30        1         1            Perreault, Miss. Anne      0      0
# ...            ...       ...                              ...    ...    ...
# male   35        3         0                  Asim, Mr. Adola      0      0
#        35        3         0  Brocklebank, Mr. William Alfred      0      0
#        35        3         0                  Cor, Mr. Bartol      0      0
#        35        3         0               Markoff, Mr. Marin      0      0
#        35        3         0             Rintamaki, Mr. Matti      0      0
#
# ...

# %%
dfdouble.loc[slice(None),['30','35'],:]
# Out:
#             pclass  survived                             name  sibsp  parch  \
# sex    age
# female 30        1         1          Bonnell, Miss. Caroline      0      0
#        30        1         1             Cherry, Miss. Gladys      0      0
#        30        1         1   Francatelli, Miss. Laura Mabel      0      0
#        30        1         1              LeRoy, Miss. Bertha      0      0
#        30        1         1            Perreault, Miss. Anne      0      0
# ...            ...       ...                              ...    ...    ...
# male   35        3         0                  Asim, Mr. Adola      0      0
#        35        3         0  Brocklebank, Mr. William Alfred      0      0
#        35        3         0                  Cor, Mr. Bartol      0      0
#        35        3         0               Markoff, Mr. Marin      0      0
#        35        3         0             Rintamaki, Mr. Matti      0      0
#
# ...

# %%
dfdouble.loc[:,['30','35'],:]
# Out:
#             pclass  survived                             name  sibsp  parch  \
# sex    age
# female 30        1         1          Bonnell, Miss. Caroline      0      0
#        30        1         1             Cherry, Miss. Gladys      0      0
#        30        1         1   Francatelli, Miss. Laura Mabel      0      0
#        30        1         1              LeRoy, Miss. Bertha      0      0
#        30        1         1            Perreault, Miss. Anne      0      0
# ...            ...       ...                              ...    ...    ...
# male   35        3         0                  Asim, Mr. Adola      0      0
#        35        3         0  Brocklebank, Mr. William Alfred      0      0
#        35        3         0                  Cor, Mr. Bartol      0      0
#        35        3         0               Markoff, Mr. Marin      0      0
#        35        3         0             Rintamaki, Mr. Matti      0      0
#
# ...

# %%
dfdouble.loc[slice(None),['30','35'],slice(None)]
# Out:
#             pclass  survived                             name  sibsp  parch  \
# sex    age
# female 30        1         1          Bonnell, Miss. Caroline      0      0
#        30        1         1             Cherry, Miss. Gladys      0      0
#        30        1         1   Francatelli, Miss. Laura Mabel      0      0
#        30        1         1              LeRoy, Miss. Bertha      0      0
#        30        1         1            Perreault, Miss. Anne      0      0
# ...            ...       ...                              ...    ...    ...
# male   35        3         0                  Asim, Mr. Adola      0      0
#        35        3         0  Brocklebank, Mr. William Alfred      0      0
#        35        3         0                  Cor, Mr. Bartol      0      0
#        35        3         0               Markoff, Mr. Marin      0      0
#        35        3         0             Rintamaki, Mr. Matti      0      0
#
# ...

# %%
dfdouble.xs('30',level='age')
# Out:
#         pclass  survived                                               name  \
# sex
# female       1         1                            Bonnell, Miss. Caroline
# female       1         1                               Cherry, Miss. Gladys
# female       1         1                     Francatelli, Miss. Laura Mabel
# female       1         1                                LeRoy, Miss. Bertha
# female       1         1                              Perreault, Miss. Anne
# female       1         1                            Serepeca, Miss. Augusta
# female       2         0              Corbett, Mrs. Walter H (Irene Colvin)
# female       2         1                     Duran y More, Miss. Florentina
# female       2         1        Renouf, Mrs. Peter Henry (Lillian Jefferys)
# female       2         1                              Sinkkonen, Miss. Anna
# female       2         1                          Slayter, Miss. Hilda Mary
# ...

# %%
dfdouble.xs('30',level=1)
# Out:
#         pclass  survived                                               name  \
# sex
# female       1         1                            Bonnell, Miss. Caroline
# female       1         1                               Cherry, Miss. Gladys
# female       1         1                     Francatelli, Miss. Laura Mabel
# female       1         1                                LeRoy, Miss. Bertha
# female       1         1                              Perreault, Miss. Anne
# female       1         1                            Serepeca, Miss. Augusta
# female       2         0              Corbett, Mrs. Walter H (Irene Colvin)
# female       2         1                     Duran y More, Miss. Florentina
# female       2         1        Renouf, Mrs. Peter Henry (Lillian Jefferys)
# female       2         1                              Sinkkonen, Miss. Anna
# female       2         1                          Slayter, Miss. Hilda Mary
# ...

# %%
dfdouble.xs('male')
# Out:
#         pclass  survived                                     name  sibsp  \
# age
# 0.3333       3         0  Danbom, Master. Gilbert Sigvard Emanuel      0
# 0.4167       3         1          Thomas, Master. Assad Alexander      0
# 0.6667       2         1                Hamalainen, Master. Viljo      1
# 0.75         3         0           Peacock, Master. Alfred Edward      1
# 0.8333       2         1            Caldwell, Master. Alden Gates      0
# ...        ...       ...                                      ...    ...
# ?            3         0                       Willey, Mr. Edward      0
# ?            3         0        Williams, Mr. Howard Hugh 'Harry'      0
# ?            3         0                   Wiseman, Mr. Phillippe      0
# ?            3         0                        Yousif, Mr. Wazli      0
# ?            3         0                    Yousseff, Mr. Gerious      0
#
#         parch              ticket     fare cabin embarked boat body  \
# age
# ...

# %%
dfdouble.xs(('male','35'),level=[0,1])
# Out:
#           pclass  survived                              name  sibsp  parch  \
# sex  age
# male 35        1         1   Homer, Mr. Harry ('Mr E Haven')      0      0
#      35        1         1            Lesurer, Mr. Gustave J      0      0
#      35        1         1  Silverthorne, Mr. Spencer Victor      0      0
#      35        2         0              Fynney, Mr. Joseph J      0      0
#      35        2         0                 Keane, Mr. Daniel      0      0
#      35        2         0         Slemen, Mr. Richard James      0      0
#      35        3         0          Allen, Mr. William Henry      0      0
#      35        3         0                   Asim, Mr. Adola      0      0
#      35        3         0   Brocklebank, Mr. William Alfred      0      0
#      35        3         0                   Cor, Mr. Bartol      0      0
#      35        3         0                Markoff, Mr. Marin      0      0
# ...

# %%
dfdouble.xs(('35','male'),level=[1,0])
# Out:
#           pclass  survived                              name  sibsp  parch  \
# sex  age
# male 35        1         1   Homer, Mr. Harry ('Mr E Haven')      0      0
#      35        1         1            Lesurer, Mr. Gustave J      0      0
#      35        1         1  Silverthorne, Mr. Spencer Victor      0      0
#      35        2         0              Fynney, Mr. Joseph J      0      0
#      35        2         0                 Keane, Mr. Daniel      0      0
#      35        2         0         Slemen, Mr. Richard James      0      0
#      35        3         0          Allen, Mr. William Henry      0      0
#      35        3         0                   Asim, Mr. Adola      0      0
#      35        3         0   Brocklebank, Mr. William Alfred      0      0
#      35        3         0                   Cor, Mr. Bartol      0      0
#      35        3         0                Markoff, Mr. Marin      0      0
# ...
