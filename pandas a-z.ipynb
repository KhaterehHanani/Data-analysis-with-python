# %%
import pandas as pd
df=pd.read_csv('documents/data.csv')

# %%
df
# Out:
#          Código  Código de barras     Marca     Tipo de Chip  Multichip  \
# 0    7275057807     7892509127547   Samsung   Nano-SIM (4FF)  Dual Chip
# 1    7248194865     7892597353132  Motorola         Nano SIM  Dual Chip
# 2    7332621276     7892509127530   Samsung   Nano-SIM (4FF)  Dual Chip
# 3    7414597353     7892597353088  Motorola  Nano SIM, e-SIM  Dual Chip
# 4    7275057022     7892509127523  Motorola         Nano SIM  Dual Chip
# ..          ...               ...       ...              ...        ...
# 188  7386528712     7892597353248   Samsung   Nano-SIM (4FF)  Dual Chip
# 189  4820514525     7892509123068   Samsung        Nano Chip  Dual Chip
# 190  7462408855     7892509126762   Samsung        Nano Chip  Dual Chip
# 191  5396424431     7892509125567  Motorola        Nano Chip  Dual Chip
# 192  7407095523     7892509125789  Motorola        Nano Chip  Dual Chip
#
#      Tipo de Tela Tamanho do Display           Resolução  \
# ...

# %%
df.head()
# Out:
#        Código  Código de barras     Marca     Tipo de Chip  Multichip  \
# 0  7275057807     7892509127547   Samsung   Nano-SIM (4FF)  Dual Chip
# 1  7248194865     7892597353132  Motorola         Nano SIM  Dual Chip
# 2  7332621276     7892509127530   Samsung   Nano-SIM (4FF)  Dual Chip
# 3  7414597353     7892597353088  Motorola  Nano SIM, e-SIM  Dual Chip
# 4  7275057022     7892509127523  Motorola         Nano SIM  Dual Chip
#
#   Tipo de Tela Tamanho do Display           Resolução  \
# 0      PLS LCD               6.6"  1080 x 2408 (FHD+)
# 1          IPS               6,5"      HD+ (720x1600)
# 2      PLS LCD               6.6"  1080 x 2408 (FHD+)
# 3          IPS               6,5"      HD+ (720x1600)
# 4          IPS               6,5"      HD+ (720x1600)
#
#                                      Câmera Traseira Câmera Frontal  ...  \
# 0                                   50MP + 5MP + 2MP           13MP  ...
# ...

# %%
df.tail(2)
# Out:
#          Código  Código de barras     Marca Tipo de Chip  Multichip  \
# 191  5396424431     7892509125567  Motorola    Nano Chip  Dual Chip
# 192  7407095523     7892509125789  Motorola    Nano Chip  Dual Chip
#
#      Tipo de Tela Tamanho do Display           Resolução    Câmera Traseira  \
# 191  Super AMOLED               6.4"  2340 x 1080 (FHD+)   48MP + 8MP + 5MP
# 192       PLS LCD              6.6''  1080 x 2408 (FHD+)  50 mp ois + 13 mp
#
#     Câmera Frontal  ...            Conexões  \
# 191           13MP  ...  Wi-Fi, 3G, 4G e 5G
# 192          32 mp  ...         Wi-Fi,3G,4G
#
#                     Alimentação, tipo de bateria  \
# 191  Bateria de Íons de Lítio de 4.500mAh Bivolt
# 192  Bateria de Íons de Lítio de 5.000mAh Bivolt
#
#                                  Conteúdo da Embalagem Garantia do Fornecedor  \
# 191  Aparelho celular, Carregador, Cabo USB, Extrat...               12 Meses
# 192  Celular. carregador. cabo usb. extrator de chi...               12 Meses
#
# ...

# %%
len(df)
# Out:
# 193

# %%
df.size
# Out:
# 5018

# %%
df.info
# Out:
# <bound method DataFrame.info of          Código  Código de barras     Marca     Tipo de Chip  Multichip  \
# 0    7275057807     7892509127547   Samsung   Nano-SIM (4FF)  Dual Chip
# 1    7248194865     7892597353132  Motorola         Nano SIM  Dual Chip
# 2    7332621276     7892509127530   Samsung   Nano-SIM (4FF)  Dual Chip
# 3    7414597353     7892597353088  Motorola  Nano SIM, e-SIM  Dual Chip
# 4    7275057022     7892509127523  Motorola         Nano SIM  Dual Chip
# ..          ...               ...       ...              ...        ...
# 188  7386528712     7892597353248   Samsung   Nano-SIM (4FF)  Dual Chip
# 189  4820514525     7892509123068   Samsung        Nano Chip  Dual Chip
# 190  7462408855     7892509126762   Samsung        Nano Chip  Dual Chip
# 191  5396424431     7892509125567  Motorola        Nano Chip  Dual Chip
# 192  7407095523     7892509125789  Motorola        Nano Chip  Dual Chip
#
#      Tipo de Tela Tamanho do Display           Resolução  \
# ...

# %%
df.shape
# Out:
# (193, 26)

# %%
df.notnull
# Out:
# <bound method DataFrame.notnull of          Código  Código de barras     Marca     Tipo de Chip  Multichip  \
# 0    7275057807     7892509127547   Samsung   Nano-SIM (4FF)  Dual Chip
# 1    7248194865     7892597353132  Motorola         Nano SIM  Dual Chip
# 2    7332621276     7892509127530   Samsung   Nano-SIM (4FF)  Dual Chip
# 3    7414597353     7892597353088  Motorola  Nano SIM, e-SIM  Dual Chip
# 4    7275057022     7892509127523  Motorola         Nano SIM  Dual Chip
# ..          ...               ...       ...              ...        ...
# 188  7386528712     7892597353248   Samsung   Nano-SIM (4FF)  Dual Chip
# 189  4820514525     7892509123068   Samsung        Nano Chip  Dual Chip
# 190  7462408855     7892509126762   Samsung        Nano Chip  Dual Chip
# 191  5396424431     7892509125567  Motorola        Nano Chip  Dual Chip
# 192  7407095523     7892509125789  Motorola        Nano Chip  Dual Chip
#
#      Tipo de Tela Tamanho do Display           Resolução  \
# ...

# %%
type(df.metod)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12912\4140556942.py in ?()
# ----> 1 type(df.metod)
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'metod'

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Código                             193 non-null    int64
#  1   Código de barras                   193 non-null    int64
#  2   Marca                              193 non-null    object
#  3   Tipo de Chip                       193 non-null    object
#  4   Multichip                          193 non-null    object
#  5   Tipo de Tela                       193 non-null    object
#  6   Tamanho do Display                 193 non-null    object
#  7   Resolução                          193 non-null    object
#  8   Câmera Traseira                    193 non-null    object
#  9   Câmera Frontal                     193 non-null    object
#  10  Filmadora                          193 non-null    object
# ...

# %%
pd.read_csv("documents/data.csv",index_col=0)
# Out:
#             Código de barras     Marca     Tipo de Chip  Multichip  \
# Código
# 7275057807     7892509127547   Samsung   Nano-SIM (4FF)  Dual Chip
# 7248194865     7892597353132  Motorola         Nano SIM  Dual Chip
# 7332621276     7892509127530   Samsung   Nano-SIM (4FF)  Dual Chip
# 7414597353     7892597353088  Motorola  Nano SIM, e-SIM  Dual Chip
# 7275057022     7892509127523  Motorola         Nano SIM  Dual Chip
# ...                      ...       ...              ...        ...
# 7386528712     7892597353248   Samsung   Nano-SIM (4FF)  Dual Chip
# 4820514525     7892509123068   Samsung        Nano Chip  Dual Chip
# 7462408855     7892509126762   Samsung        Nano Chip  Dual Chip
# 5396424431     7892509125567  Motorola        Nano Chip  Dual Chip
# 7407095523     7892509125789  Motorola        Nano Chip  Dual Chip
#
#             Tipo de Tela Tamanho do Display           Resolução  \
# Código
# 7275057807       PLS LCD               6.6"  1080 x 2408 (FHD+)
# ...

# %%
df.min()
# Out:
# Código                                                                      4342102672
# Código de barras                                                         7892509120968
# Marca                                                                         Motorola
# Tipo de Chip                                                                 Nano Chip
# Multichip                                                                    Dual Chip
# Tipo de Tela                                              Dynamic AMOLED 2X (24-120Hz)
# Tamanho do Display                                                                6,5"
# Resolução                                                           1080 x 2340 (FHD+)
# Câmera Traseira                                                 108MP + 8MP + 2MP+ 2MP
# Câmera Frontal                                                                    10MP
# Filmadora                                                            FHD (1920 x 1080)
# ...

# %%
len(df)
# Out:
# 193

# %%
df.tail(7)
# Out:
#          Código  Código de barras     Marca    Tipo de Chip  Multichip  \
# 186  7274983198     7892509127554   SAMSUNG       Nano Chip  Dual Chip
# 187  7275031404     7892509128070   Samsung  Nano-SIM (4FF)  Dual Chip
# 188  7386528712     7892597353248   Samsung  Nano-SIM (4FF)  Dual Chip
# 189  4820514525     7892509123068   Samsung       Nano Chip  Dual Chip
# 190  7462408855     7892509126762   Samsung       Nano Chip  Dual Chip
# 191  5396424431     7892509125567  Motorola       Nano Chip  Dual Chip
# 192  7407095523     7892509125789  Motorola       Nano Chip  Dual Chip
#
#      Tipo de Tela Tamanho do Display           Resolução  \
# 186       PLS LCD              6.6''  1080 x 2408 (FHD+)
# 187  Super AMOLED               6.4"  1080 x 2340 (FHD+)
# 188  Super AMOLED               6.6"  1080 x 2340 (FHD+)
# 189  Super AMOLED              6.5''  1080 x 2400 (FHD+)
# 190       LCD TFT              6.5''    720 x 1600 (HD+)
# ...

# %%
df.tail(7)
# Out:
#          Código  Código de barras     Marca    Tipo de Chip  Multichip  \
# 186  7274983198     7892509127554   SAMSUNG       Nano Chip  Dual Chip
# 187  7275031404     7892509128070   Samsung  Nano-SIM (4FF)  Dual Chip
# 188  7386528712     7892597353248   Samsung  Nano-SIM (4FF)  Dual Chip
# 189  4820514525     7892509123068   Samsung       Nano Chip  Dual Chip
# 190  7462408855     7892509126762   Samsung       Nano Chip  Dual Chip
# 191  5396424431     7892509125567  Motorola       Nano Chip  Dual Chip
# 192  7407095523     7892509125789  Motorola       Nano Chip  Dual Chip
#
#      Tipo de Tela Tamanho do Display           Resolução  \
# 186       PLS LCD              6.6''  1080 x 2408 (FHD+)
# 187  Super AMOLED               6.4"  1080 x 2340 (FHD+)
# 188  Super AMOLED               6.6"  1080 x 2340 (FHD+)
# 189  Super AMOLED              6.5''  1080 x 2400 (FHD+)
# 190       LCD TFT              6.5''    720 x 1600 (HD+)
# ...

# %%
df.tail(7).head(2).sum(numeric_only=True)
# Out:
# Código                 14550014602
# Código de barras    15785018255624
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 193 entries, 0 to 192
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Código                             193 non-null    int64
#  1   Código de barras                   193 non-null    int64
#  2   Marca                              193 non-null    object
#  3   Tipo de Chip                       193 non-null    object
#  4   Multichip                          193 non-null    object
#  5   Tipo de Tela                       193 non-null    object
#  6   Tamanho do Display                 193 non-null    object
#  7   Resolução                          193 non-null    object
#  8   Câmera Traseira                    193 non-null    object
#  9   Câmera Frontal                     193 non-null    object
#  10  Filmadora                          193 non-null    object
# ...

# %%
df.describe()
# Out:
#              Código  Código de barras
# count  1.930000e+02      1.930000e+02
# mean   6.645542e+09      7.892537e+12
# std    1.070945e+09      4.130497e+07
# min    4.342103e+09      7.892509e+12
# 25%    5.396424e+09      7.892509e+12
# 50%    7.275057e+09      7.892509e+12
# 75%    7.407096e+09      7.892597e+12
# max    7.468566e+09      7.892597e+12

# %%
t1=df.head(5)

# %%
t1.describe()
# Out:
#              Código  Código de barras
# count  5.000000e+00      5.000000e+00
# mean   7.309106e+09      7.892544e+12
# std    6.653979e+07      4.832314e+07
# min    7.248195e+09      7.892509e+12
# 25%    7.275057e+09      7.892509e+12
# 50%    7.275058e+09      7.892509e+12
# 75%    7.332621e+09      7.892597e+12
# max    7.414597e+09      7.892597e+12

# %%
t1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 26 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Código                             5 non-null      int64
#  1   Código de barras                   5 non-null      int64
#  2   Marca                              5 non-null      object
#  3   Tipo de Chip                       5 non-null      object
#  4   Multichip                          5 non-null      object
#  5   Tipo de Tela                       5 non-null      object
#  6   Tamanho do Display                 5 non-null      object
#  7   Resolução                          5 non-null      object
#  8   Câmera Traseira                    5 non-null      object
#  9   Câmera Frontal                     5 non-null      object
#  10  Filmadora                          5 non-null      object
# ...

# %%
t1.mean(numeric_only= True)
# Out:
# Código              7.309106e+09
# Código de barras    7.892544e+12
# dtype: float64

# %%
t1.max
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.max of        Código  Código de barras     Marca     Tipo de Chip  Multichip  \
# 0  7275057807     7892509127547   Samsung   Nano-SIM (4FF)  Dual Chip
# 1  7248194865     7892597353132  Motorola         Nano SIM  Dual Chip
# 2  7332621276     7892509127530   Samsung   Nano-SIM (4FF)  Dual Chip
# 3  7414597353     7892597353088  Motorola  Nano SIM, e-SIM  Dual Chip
# 4  7275057022     7892509127523  Motorola         Nano SIM  Dual Chip
#
#   Tipo de Tela Tamanho do Display           Resolução  \
# 0      PLS LCD               6.6"  1080 x 2408 (FHD+)
# 1          IPS               6,5"      HD+ (720x1600)
# 2      PLS LCD               6.6"  1080 x 2408 (FHD+)
# 3          IPS               6,5"      HD+ (720x1600)
# 4          IPS               6,5"      HD+ (720x1600)
#
#                                      Câmera Traseira Câmera Frontal  ...  \
# 0                                   50MP + 5MP + 2MP           13MP  ...
# ...

# %%
df.describe(include="O")
# Out:
#           Marca Tipo de Chip  Multichip  Tipo de Tela Tamanho do Display  \
# count       193          193        193           193                193
# unique        5            5          1             9                  8
# top     Samsung    Nano Chip  Dual Chip  Super AMOLED              6.5''
# freq         88          136        193            69                 72
#
#                  Resolução         Câmera Traseira Câmera Frontal Filmadora  \
# count                  193                     193            193       193
# unique                   8                      21             10         5
# top     1080 x 2408 (FHD+)  50MP + 5MP + 2MP + 2MP           32MP   Full HD
# freq                    57                      22             51       100
#
#        Processador  ...            Conexões  \
# count          193  ...                 193
# unique          18  ...                   7
# top      Octa-Core  ...  Wi-Fi, 3G, 4G e 5G
# ...

# %%
tit=pd.read_csv("downloads/Titanic-Dataset.csv")

# %%
tit.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
tit.describe(include="O")
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
tit.describe(include=["object","int64"])
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#              SibSp       Parch  Ticket    Cabin Embarked
# ...

# %%
tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
tit.sum(numeric_only=True)
# Out:
# PassengerId    397386.0000
# Survived          342.0000
# Pclass           2057.0000
# Age             21205.1700
# SibSp             466.0000
# Parch             340.0000
# Fare            28693.9493
# dtype: float64

# %%
tit
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 tit
#
# NameError: name 'tit' is not defined

# %%
tit.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 tit.info()
#
# NameError: name 'tit' is not defined

# %%
tit=pd.read_csv("downloads/Titanic-Dataset.csv")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 tit=pd.read_csv("downloads/Titanic-Dataset.csv")
#
# NameError: name 'pd' is not defined

# %%
import pandas as pd

# %%
tit=pd.read_csv("downloads/Titanic-Dataset.csv")

# %%
tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
tit
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
sur=tit.survived
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14364\3779238211.py in ?()
# ----> 1 sur=tit.survived
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'survived'

# %%
sur=tit['Survived']
sur
# Out:
# 0      0
# 1      1
# 2      1
# 3      1
# 4      0
#       ..
# 886    0
# 887    1
# 888    0
# 889    1
# 890    0
# Name: Survived, Length: 891, dtype: int64

# %%
type(sur)
# Out:
# pandas.core.series.Series

# %%
tit.Survived.sum()
# Out:
# 342

# %%
mins=tit.min(numeric_only=True)

# %%
mins
# Out:
# PassengerId    1.00
# Survived       0.00
# Pclass         1.00
# Age            0.42
# SibSp          0.00
# Parch          0.00
# Fare           0.00
# dtype: float64

# %%
mins.index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
mins
# Out:
# PassengerId    1.00
# Survived       0.00
# Pclass         1.00
# Age            0.42
# SibSp          0.00
# Parch          0.00
# Fare           0.00
# dtype: float64

# %%
mins.values
# Out:
# array([1.  , 0.  , 1.  , 0.42, 0.  , 0.  , 0.  ])

# %%
mins.shape
# Out:
# (7,)

# %%
mins.index
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Age', 'SibSp', 'Parch', 'Fare'], dtype='object')

# %%
import pandas as pd
house=pd.read_csv('Downloads/Houses.csv')

# %%
best=pd.read_csv('Downloads/bestsellers.csv')

# %%
best
# Out:
#                                                   Name                 Author  \
# 0    Act Like a Lady, Think Like a Man: What Men Re...           Steve Harvey
# 1    Arguing with Idiots: How to Stop Small Minds a...             Glenn Beck
# 2            Breaking Dawn (The Twilight Saga, Book 4)        Stephenie Meyer
# 3          Crazy Love: Overwhelmed by a Relentless God           Francis Chan
# 4    Dead And Gone: A Sookie Stackhouse Novel (Sook...       Charlaine Harris
# ..                                                 ...                    ...
# 695                   The Wonderful Things You Will Be  Emily Winfield Martin
# 696                                 Ugly Love: A Novel         Colleen Hoover
# 697                                             Verity         Colleen Hoover
# 698               What to Expect When You're Expecting          Heidi Murkoff
# 699                            Where the Crawdads Sing            Delia Owens
#
# ...

# %%
best["Name"]
# Out:
# 0      Act Like a Lady, Think Like a Man: What Men Re...
# 1      Arguing with Idiots: How to Stop Small Minds a...
# 2              Breaking Dawn (The Twilight Saga, Book 4)
# 3            Crazy Love: Overwhelmed by a Relentless God
# 4      Dead And Gone: A Sookie Stackhouse Novel (Sook...
#                              ...
# 695                     The Wonderful Things You Will Be
# 696                                   Ugly Love: A Novel
# 697                                               Verity
# 698                 What to Expect When You're Expecting
# 699                              Where the Crawdads Sing
# Name: Name, Length: 700, dtype: object

# %% [markdown]
# best.Authers.head(8)

# %%
best.Author.head(8)
# Out:
# 0        Steve Harvey
# 1          Glenn Beck
# 2     Stephenie Meyer
# 3        Francis Chan
# 4    Charlaine Harris
# 5         Jeff Kinney
# 6        Zhi Gang Sha
# 7         Jeff Kinney
# Name: Author, dtype: object

# %%
best.Genre.unique()
# Out:
# array(['Non Fiction', 'Fiction'], dtype=object)

# %%
best.Genre.nunique()
# Out:
# 2

# %%
best.Price.plot()
# Out:
# <Axes: >

# %%
import pandas as pd
bes=pd.read_csv("downloads/bestsellers.csv")

# %%
bes
# Out:
#                                                   Name                 Author  \
# 0    Act Like a Lady, Think Like a Man: What Men Re...           Steve Harvey
# 1    Arguing with Idiots: How to Stop Small Minds a...             Glenn Beck
# 2            Breaking Dawn (The Twilight Saga, Book 4)        Stephenie Meyer
# 3          Crazy Love: Overwhelmed by a Relentless God           Francis Chan
# 4    Dead And Gone: A Sookie Stackhouse Novel (Sook...       Charlaine Harris
# ..                                                 ...                    ...
# 695                   The Wonderful Things You Will Be  Emily Winfield Martin
# 696                                 Ugly Love: A Novel         Colleen Hoover
# 697                                             Verity         Colleen Hoover
# 698               What to Expect When You're Expecting          Heidi Murkoff
# 699                            Where the Crawdads Sing            Delia Owens
#
# ...

# %%
bes["Name"].value_counts().head(3)
# Out:
# Name
# Publication Manual of the American Psychological Association, 6th Edition    10
# The Very Hungry Caterpillar                                                  10
# StrengthsFinder 2.0                                                           9
# Name: count, dtype: int64

# %%
bes[["Author","User Rating"]]
# Out:
#                     Author  User Rating
# 0             Steve Harvey          4.6
# 1               Glenn Beck          4.6
# 2          Stephenie Meyer          4.6
# 3             Francis Chan          4.7
# 4         Charlaine Harris          4.6
# ..                     ...          ...
# 695  Emily Winfield Martin          4.9
# 696         Colleen Hoover          4.7
# 697         Colleen Hoover          4.6
# 698          Heidi Murkoff          4.8
# 699            Delia Owens          4.8
#
# [700 rows x 2 columns]

# %%
bes.value_counts()
# Out:
# Name                                                                                                                Author                           User Rating  Reviews  Price  Year  Genre
# 10-Day Green Smoothie Cleanse                                                                                       JJ Smith                         4.7          17350    8      2016  Non Fiction    1
# The Fault in Our Stars                                                                                              John Green                       4.7          50482    7      2014  Fiction        1
# The Constitution of the United States                                                                               Delegates of the Constitutional  4.8          2774     0      2016  Non Fiction    1
# ...

# %%
bes[["Author","User Rating"]].value_counts()
# Out:
# Author                              User Rating
# Jeff Kinney                         4.8            10
# American Psychological Association  4.5            10
# Eric Carle                          4.9            10
# Dav Pilkey                          4.9             9
# Gallup                              4.0             9
#                                                    ..
# Kristin Hannah                      4.5             1
# DK                                  4.5             1
# Larry Schweikart                    4.6             1
# Crispin Boyer                       4.8             1
# Maurice Sendak                      4.8             1
# Name: count, Length: 369, dtype: int64

# %%
bes1=bes[["Author","User Rating"]]

# %%
bes1
# Out:
# Author                              User Rating
# Jeff Kinney                         4.8            10
# American Psychological Association  4.5            10
# Eric Carle                          4.9            10
# Dav Pilkey                          4.9             9
# Gallup                              4.0             9
#                                                    ..
# Kristin Hannah                      4.5             1
# DK                                  4.5             1
# Larry Schweikart                    4.6             1
# Crispin Boyer                       4.8             1
# Maurice Sendak                      4.8             1
# Name: count, Length: 369, dtype: int64

# %%
bes1.value_counts()
# Out:
# count
# 1     222
# 2      76
# 3      31
# 4      13
# 5      12
# 9       5
# 6       4
# 10      3
# 7       2
# 8       1
# Name: count, dtype: int64

# %%
bes1
# Out:
#                     Author  User Rating
# 0             Steve Harvey          4.6
# 1               Glenn Beck          4.6
# 2          Stephenie Meyer          4.6
# 3             Francis Chan          4.7
# 4         Charlaine Harris          4.6
# ..                     ...          ...
# 695  Emily Winfield Martin          4.9
# 696         Colleen Hoover          4.7
# 697         Colleen Hoover          4.6
# 698          Heidi Murkoff          4.8
# 699            Delia Owens          4.8
#
# [700 rows x 2 columns]

# %%
bes1.value_counts()
# Out:
# Author                              User Rating
# Jeff Kinney                         4.8            10
# American Psychological Association  4.5            10
# Eric Carle                          4.9            10
# Dav Pilkey                          4.9             9
# Gallup                              4.0             9
#                                                    ..
# Kristin Hannah                      4.5             1
# DK                                  4.5             1
# Larry Schweikart                    4.6             1
# Crispin Boyer                       4.8             1
# Maurice Sendak                      4.8             1
# Name: count, Length: 369, dtype: int64

# %%
bes1[["Author","User Rating"]].value_counts()
# Out:
# Author                              User Rating
# Jeff Kinney                         4.8            10
# American Psychological Association  4.5            10
# Eric Carle                          4.9            10
# Dav Pilkey                          4.9             9
# Gallup                              4.0             9
#                                                    ..
# Kristin Hannah                      4.5             1
# DK                                  4.5             1
# Larry Schweikart                    4.6             1
# Crispin Boyer                       4.8             1
# Maurice Sendak                      4.8             1
# Name: count, Length: 369, dtype: int64

# %%
bes1[["Author","User Rating"]].value_counts().nlargest(1)
# Out:
# Author       User Rating
# Jeff Kinney  4.8            10
# Name: count, dtype: int64

# %%
bes
# Out:
#                                                   Name                 Author  \
# 0    Act Like a Lady, Think Like a Man: What Men Re...           Steve Harvey
# 1    Arguing with Idiots: How to Stop Small Minds a...             Glenn Beck
# 2            Breaking Dawn (The Twilight Saga, Book 4)        Stephenie Meyer
# 3          Crazy Love: Overwhelmed by a Relentless God           Francis Chan
# 4    Dead And Gone: A Sookie Stackhouse Novel (Sook...       Charlaine Harris
# ..                                                 ...                    ...
# 695                   The Wonderful Things You Will Be  Emily Winfield Martin
# 696                                 Ugly Love: A Novel         Colleen Hoover
# 697                                             Verity         Colleen Hoover
# 698               What to Expect When You're Expecting          Heidi Murkoff
# 699                            Where the Crawdads Sing            Delia Owens
#
# ...

# %%
bes.nlargest(3,["Price"])
# Out:
#                                                   Name  \
# 204  Diagnostic and Statistical Manual of Mental Di...
# 253  Diagnostic and Statistical Manual of Mental Di...
# 43                        The Twilight Saga Collection
#
#                                Author  User Rating  Reviews  Price  Year  \
# 204  American Psychiatric Association          4.5     6679    105  2013
# 253  American Psychiatric Association          4.5     6679    105  2014
# 43                    Stephenie Meyer          4.7     3801     82  2009
#
#            Genre
# 204  Non Fiction
# 253  Non Fiction
# 43       Fiction

# %%
bes.Price.nlargest(3)
# Out:
# 204    105
# 253    105
# 43      82
# Name: Price, dtype: int64

# %%
bes.nlargest(3,["Price","User Rating"])
# Out:
#                                                   Name  \
# 204  Diagnostic and Statistical Manual of Mental Di...
# 253  Diagnostic and Statistical Manual of Mental Di...
# 43                        The Twilight Saga Collection
#
#                                Author  User Rating  Reviews  Price  Year  \
# 204  American Psychiatric Association          4.5     6679    105  2013
# 253  American Psychiatric Association          4.5     6679    105  2014
# 43                    Stephenie Meyer          4.7     3801     82  2009
#
#            Genre
# 204  Non Fiction
# 253  Non Fiction
# 43       Fiction

# %%
bes.Price.nlargest(3,keep="all")
# Out:
# 204    105
# 253    105
# 43      82
# Name: Price, dtype: int64

# %%
bes.Price.nlargest(3,keep="first")
# Out:
# 204    105
# 253    105
# 43      82
# Name: Price, dtype: int64

# %%
bes.Price.nlargest(3,keep="last")
# Out:
# 253    105
# 204    105
# 43      82
# Name: Price, dtype: int64

# %%
bes[["Author","User Rating","Price"]].describe()
# Out:
#        User Rating       Price
# count   700.000000  700.000000
# mean      4.639857   12.700000
# std       0.218586    9.915162
# min       3.300000    0.000000
# 25%       4.500000    7.000000
# 50%       4.700000   11.000000
# 75%       4.800000   15.000000
# max       4.900000  105.000000

# %%
bes[["Author","User Rating","Price"]].describe(include=["object","int64","float"])
# Out:
#              Author  User Rating       Price
# count           700   700.000000  700.000000
# unique          305          NaN         NaN
# top     Jeff Kinney          NaN         NaN
# freq             14          NaN         NaN
# mean            NaN     4.639857   12.700000
# std             NaN     0.218586    9.915162
# min             NaN     3.300000    0.000000
# 25%             NaN     4.500000    7.000000
# 50%             NaN     4.700000   11.000000
# 75%             NaN     4.800000   15.000000
# max             NaN     4.900000  105.000000

# %%
bes["Author"].value_counts()
# Out:
# Author
# Jeff Kinney                           False
# Gary Chapman                          False
# Suzanne Collins                       False
# Rick Riordan                          False
# American Psychological Association    False
#                                       ...
# Randall Munroe                         True
# Coloring Books for Adults              True
# Chris Kyle                             True
# Angie Grace                            True
# Stephen Perrine                        True
# Name: count, Length: 305, dtype: bool

# %%
bes["Author"].value_counts()
# Out:
# Author
# Jeff Kinney                           14
# Gary Chapman                          14
# Suzanne Collins                       12
# Rick Riordan                          11
# American Psychological Association    11
#                                       ..
# Randall Munroe                         1
# Coloring Books for Adults              1
# Chris Kyle                             1
# Angie Grace                            1
# Stephen Perrine                        1
# Name: count, Length: 305, dtype: int64

# %%
bes["Author"].value_counts().nlargest(10).plot(kind="bar")
# Out:
# <Axes: xlabel='Author'>

# %%
bes["Author"].nunique()
# Out:
# 305

# %%
bes["Genre"].nunique(dropna='False')
# Out:
# 2

# %%
bes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         700 non-null    object
#  1   Author       700 non-null    object
#  2   User Rating  700 non-null    float64
#  3   Reviews      700 non-null    int64
#  4   Price        700 non-null    int64
#  5   Year         700 non-null    int64
#  6   Genre        700 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 38.4+ KB

# %%
best=bes.Price

# %%
best.values
# Out:
# array([ 17,   5,  13,  14,   4,  15,   6,  12,   1,  14,   7,  18,  11,
#          6,  14,   4,   7,  15,  27,  10,  12,  20,  46,  25,  17,  18,
#         12,  24,  53,  11,   6,   9,  16,   2,  10,   6,   9,   7,  19,
#         13,   8,   6,   9,  82,  11,  15,   9,  20,  42,  13,   2,  14,
#         21,   8,  11,  14,  11,   8,  17,  15,  16,   9,   9,  20,  14,
#         18,  10,   8,  20,   2,  46,   9,  10,  11,  17,  13,  20,  28,
#         10,  17,  13,  11,   6,  14,   9,   2,   6,  14,  13,   7,  14,
#         40,  12,  14,   0,  12,  11,  21,  16,  11,  22,  11,  32,   0,
#         11,  14,  11,   4,   9,   5,   9,  14,  10,  21,  20,   8,  10,
#         13,   8,  13,  46,   9,  20,  17,  20,  22,  21,  28,  24,  10,
#         21,  15,   6,  14,   8,   7,   8,  30,   9,  13,  18,  40,  16,
#         10,  10,  19,  12,  16,  12,   9,  24,  11,   9,   7,  11,  14,
#         32,   5,  10,  14,   7,  10,   8,  25,  10,   8,  14,   8,  13,
# ...

# %%
best.index
# Out:
# RangeIndex(start=0, stop=700, step=1)

# %%
best.shape
# Out:
# (700,)

# %%
best.dtype
# Out:
# dtype('int64')

# %%
type(best)
# Out:
# pandas.core.series.Series

# %%
bes.min()
# Out:
# Name           10-Day Green Smoothie Cleanse
# Author                      Abraham Verghese
# User Rating                              3.3
# Reviews                                   37
# Price                                      0
# Year                                    2009
# Genre                                Fiction
# dtype: object

# %%
best.info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 700 entries, 0 to 699
# Series name: Price
# Non-Null Count  Dtype
# --------------  -----
# 700 non-null    int64
# dtypes: int64(1)
# memory usage: 5.6 KB

# %%
best.describe()
# Out:
# count    700.000000
# mean      12.700000
# std        9.915162
# min        0.000000
# 25%        7.000000
# 50%       11.000000
# 75%       15.000000
# max      105.000000
# Name: Price, dtype: float64

# %%
bes["Price"].describe()
# Out:
# count    700.000000
# mean      12.700000
# std        9.915162
# min        0.000000
# 25%        7.000000
# 50%       11.000000
# 75%       15.000000
# max      105.000000
# Name: Price, dtype: float64

# %%
pd.read_csv("downloads/Bitcoin.csv")
# Out:
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...          ...           ...           ...           ...           ...
# 2742  2022-03-21  41246.132813  41454.410156  40668.042969  41077.996094
# 2743  2022-03-22  41074.105469  43124.707031  40948.281250  42358.808594
# 2744  2022-03-23  42364.378906  42893.507813  41877.507813  42892.957031
# 2745  2022-03-24  42886.652344  44131.855469  42726.164063  43960.933594
# 2746  2022-03-25  43958.675781  44982.519531  43711.871094  44395.964844
#
#          Adj Close       Volume
# 0       457.334015     21056800
# ...

# %%
bit=pd.read_csv("downloads/Bitcoin.csv")
bit
# Out:
#             Date          Open          High           Low         Close  \
# 0     2014-09-17    465.864014    468.174011    452.421997    457.334015
# 1     2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2     2014-09-19    424.102997    427.834991    384.532013    394.795990
# 3     2014-09-20    394.673004    423.295990    389.882996    408.903992
# 4     2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...          ...           ...           ...           ...           ...
# 2742  2022-03-21  41246.132813  41454.410156  40668.042969  41077.996094
# 2743  2022-03-22  41074.105469  43124.707031  40948.281250  42358.808594
# 2744  2022-03-23  42364.378906  42893.507813  41877.507813  42892.957031
# 2745  2022-03-24  42886.652344  44131.855469  42726.164063  43960.933594
# 2746  2022-03-25  43958.675781  44982.519531  43711.871094  44395.964844
#
#          Adj Close       Volume
# 0       457.334015     21056800
# ...

# %%
b=bit[["Date","Open"]]
b.plot(x="Date",y="Open")
# Out:
# <Axes: xlabel='Date'>

# %% [raw]
# bit.set_index("Date",inplace=True).plot()

# %%
bit.plot()
# Out:
# <Axes: >

# %%
bit.set_index("Date",inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12656\2009690155.py in ?()
# ----> 1 bit.set_index("Date",inplace=True)
#
# ~\anaconda3\Lib\site-packages\pandas\core\frame.py in ?(self, keys, drop, append, inplace, verify_integrity)
#    5855                     if not found:
#    5856                         missing.append(col)
#    5857
#    5858         if missing:
# -> 5859             raise KeyError(f"None of {missing} are in the columns")
#    5860
#    5861         if inplace:
#    5862             frame = self
#
# KeyError: "None of ['Date'] are in the columns"

# %%
bit
# Out:
#                     Open          High           Low         Close  \
# Date
# 2014-09-17    465.864014    468.174011    452.421997    457.334015
# 2014-09-18    456.859985    456.859985    413.104004    424.440002
# 2014-09-19    424.102997    427.834991    384.532013    394.795990
# 2014-09-20    394.673004    423.295990    389.882996    408.903992
# 2014-09-21    408.084991    412.425995    393.181000    398.821014
# ...                  ...           ...           ...           ...
# 2022-03-21  41246.132813  41454.410156  40668.042969  41077.996094
# 2022-03-22  41074.105469  43124.707031  40948.281250  42358.808594
# 2022-03-23  42364.378906  42893.507813  41877.507813  42892.957031
# 2022-03-24  42886.652344  44131.855469  42726.164063  43960.933594
# 2022-03-25  43958.675781  44982.519531  43711.871094  44395.964844
#
#                Adj Close       Volume
# Date
# 2014-09-17    457.334015     21056800
# 2014-09-18    424.440002     34483200
# ...

# %%
bit.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
import pandas as pd
pok=pd.read_csv("downloads/Pokemon.csv")

# %%
pok
# Out:
#        #                   Name   Type 1  Type 2  Total  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison    318  45      49       49
# 1      2                Ivysaur    Grass  Poison    405  60      62       63
# 2      3               Venusaur    Grass  Poison    525  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison    625  80     100      123
# 4      4             Charmander     Fire     NaN    309  39      52       43
# ..   ...                    ...      ...     ...    ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy    600  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy    700  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost    600  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark    680  80     160       60
# 799  721              Volcanion     Fire   Water    600  80     110      120
#
# ...

# %%
pok.set_index("Name")
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                1    Grass  Poison    318  45      49       49
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
pok.set_index("Name",inplace=True)

# %%
pok
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                1    Grass  Poison    318  45      49       49
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
pok.sort_values("Attack",ascending=False)
# Out:
#                            #   Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# MewtwoMega Mewtwo X      150  Psychic  Fighting    780  106     190      100
# HeracrossMega Heracross  214      Bug  Fighting    600   80     185      115
# GroudonPrimal Groudon    383   Ground      Fire    770  100     180      160
# RayquazaMega Rayquaza    384   Dragon    Flying    780  105     180      100
# DeoxysAttack Forme       386  Psychic       NaN    600   50     180       20
# ...                      ...      ...       ...    ...  ...     ...      ...
# Magikarp                 129    Water       NaN    200   20      10       55
# Blissey                  242   Normal       NaN    540  255      10       10
# Shuckle                  213      Bug      Rock    505   20      10      230
# Chansey                  113   Normal       NaN    450  250       5        5
# Happiny                  440   Normal       NaN    220  100       5        5
#
# ...

# %%
pok.sort_values("#",inplace=True)

# %%
pok.sort_values(["Total","Attack"],ascending=False)
# Out:
#                          #   Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# MewtwoMega Mewtwo X    150  Psychic  Fighting    780  106     190      100
# RayquazaMega Rayquaza  384   Dragon    Flying    780  105     180      100
# MewtwoMega Mewtwo Y    150  Psychic       NaN    780  106     150       70
# GroudonPrimal Groudon  383   Ground      Fire    770  100     180      160
# KyogrePrimal Kyogre    382    Water       NaN    770  100     150       90
# ...                    ...      ...       ...    ...  ...     ...      ...
# Weedle                  13      Bug    Poison    195   40      35       30
# Caterpie                10      Bug       NaN    195   45      30       35
# Kricketot              401      Bug       NaN    194   37      25       41
# Azurill                298   Normal     Fairy    190   50      20       40
# Sunkern                191    Grass       NaN    180   30      30       30
#
# ...

# %%
pok.sort_index()
# Out:
#                            #   Type 1  Type 2  Total   HP  Attack  Defense  \
# Name
# Abomasnow                460    Grass     Ice    494   90      92       75
# AbomasnowMega Abomasnow  460    Grass     Ice    594   90     132      105
# Abra                      63  Psychic     NaN    310   25      20       15
# Absol                    359     Dark     NaN    465   65     130       60
# AbsolMega Absol          359     Dark     NaN    565   65     150       60
# ...                      ...      ...     ...    ...  ...     ...      ...
# Zoroark                  571     Dark     NaN    510   60     105       60
# Zorua                    570     Dark     NaN    330   40      65       40
# Zubat                     41   Poison  Flying    245   40      45       35
# Zweilous                 634     Dark  Dragon    420   72      85       70
# Zygarde50% Forme         718   Dragon  Ground    600  108     100      121
#
# ...

# %%
pok.Speed.nlargest(10).mean()
# Out:
# 151.5

# %%
x=pok.Speed.nlargest(10)

# %%
x.describe()
# Out:
# count     10.000000
# mean     151.500000
# std       11.316163
# min      140.000000
# 25%      145.000000
# 50%      150.000000
# 75%      150.000000
# max      180.000000
# Name: Speed, dtype: float64

# %%
pok.nlargest(20,["Attack"])
# Out:
#                            #   Type 1    Type 2  Total   HP  Attack  Defense  \
# Name
# MewtwoMega Mewtwo X      150  Psychic  Fighting    780  106     190      100
# HeracrossMega Heracross  214      Bug  Fighting    600   80     185      115
# GroudonPrimal Groudon    383   Ground      Fire    770  100     180      160
# RayquazaMega Rayquaza    384   Dragon    Flying    780  105     180      100
# DeoxysAttack Forme       386  Psychic       NaN    600   50     180       20
# GarchompMega Garchomp    445   Dragon    Ground    700  108     170      115
# KyuremBlack Kyurem       646   Dragon       Ice    700  125     170      100
# BanetteMega Banette      354    Ghost       NaN    555   64     165       75
# Rampardos                409     Rock       NaN    495   97     165       60
# GalladeMega Gallade      475  Psychic  Fighting    618   68     165       95
# TyranitarMega Tyranitar  248     Rock      Dark    700  100     164      150
# ...

# %%
pok.nlargest(20,["Attack"]).value_counts("Type 1").nlargest(1)
# Out:
# Type 1
# Psychic    5
# Name: count, dtype: int64

# %%
pok.loc[["Diglett"]]
# Out:
#           #  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Diglett  50  Ground    NaN    265  10      55       25       35       45
#
#          Speed  Generation  Legendary
# Name
# Diglett     95           1      False

# %%
pok.loc["Diglett"]
# Out:
# #                 50
# Type 1        Ground
# Type 2           NaN
# Total            265
# HP                10
# Attack            55
# Defense           25
# Sp. Atk           35
# Sp. Def           45
# Speed             95
# Generation         1
# Legendary      False
# Name: Diglett, dtype: object

# %%
pok.loc[["Vulpix","Eevee"]]
# Out:
#           #  Type 1 Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Vulpix   37    Fire    NaN    299  38      41       40       50       65
# Eevee   133  Normal    NaN    325  55      55       50       45       65
#
#         Speed  Generation  Legendary
# Name
# Vulpix     65           1      False
# Eevee      55           1      False

# %%
pok.iloc[[40,50,60]]
# Out:
#             # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Clefairy   35  Fairy     NaN    323  70      45       48       60       65
# Vileplume  45  Grass  Poison    490  75      80       85      110       90
# Golduck    55  Water     NaN    500  80      82       78       95       80
#
#            Speed  Generation  Legendary
# Name
# Clefairy      35           1      False
# Vileplume     50           1      False
# Golduck       85           1      False

# %%
pok
# Out:
#                          #   Type 1  Type 2  Total  HP  Attack  Defense  \
# Name
# Bulbasaur                1    Grass  Poison    318  45      49       49
# Ivysaur                  2    Grass  Poison    405  60      62       63
# Venusaur                 3    Grass  Poison    525  80      82       83
# VenusaurMega Venusaur    3    Grass  Poison    625  80     100      123
# Charmander               4     Fire     NaN    309  39      52       43
# ...                    ...      ...     ...    ...  ..     ...      ...
# Diancie                719     Rock   Fairy    600  50     100      150
# DiancieMega Diancie    719     Rock   Fairy    700  50     160      110
# HoopaHoopa Unbound     720  Psychic    Dark    680  80     160       60
# HoopaHoopa Confined    720  Psychic   Ghost    600  80     110       60
# Volcanion              721     Fire   Water    600  80     110      120
#
#                        Sp. Atk  Sp. Def  Speed  Generation  Legendary
# Name
# ...

# %%
x=["Bulbasaur","Ivysaur"]
pok.loc[x]
# Out:
#            # Type 1  Type 2  Total  HP  Attack  Defense  Sp. Atk  Sp. Def  \
# Name
# Bulbasaur  1  Grass  Poison    318  45      49       49       65       65
# Ivysaur    2  Grass  Poison    405  60      62       63       80       80
#
#            Speed  Generation  Legendary
# Name
# Bulbasaur     45           1      False
# Ivysaur       60           1      False

# %%
type(x)
# Out:
# list

# %%
pok.loc[x].Attack.plot(kind="bar")
# Out:
# <Axes: xlabel='Name'>

# %%
import pandas as pd
bes=pd.read_csv("Downloads/bestsellers.csv")

# %%
bes.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 700 entries, 0 to 699
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         700 non-null    object
#  1   Author       700 non-null    object
#  2   User Rating  700 non-null    float64
#  3   Reviews      700 non-null    int64
#  4   Price        700 non-null    int64
#  5   Year         700 non-null    int64
#  6   Genre        700 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 38.4+ KB

# %%
bes
# Out:
#                                                   Name                 Author  \
# 0    Act Like a Lady, Think Like a Man: What Men Re...           Steve Harvey
# 1    Arguing with Idiots: How to Stop Small Minds a...             Glenn Beck
# 2            Breaking Dawn (The Twilight Saga, Book 4)        Stephenie Meyer
# 3          Crazy Love: Overwhelmed by a Relentless God           Francis Chan
# 4    Dead And Gone: A Sookie Stackhouse Novel (Sook...       Charlaine Harris
# ..                                                 ...                    ...
# 695                   The Wonderful Things You Will Be  Emily Winfield Martin
# 696                                 Ugly Love: A Novel         Colleen Hoover
# 697                                             Verity         Colleen Hoover
# 698               What to Expect When You're Expecting          Heidi Murkoff
# 699                            Where the Crawdads Sing            Delia Owens
#
# ...

# %%
bes[bes[Author]=='Francis Chan']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 bes[bes[Author]=='Francis Chan']
#
# NameError: name 'Author' is not defined

# %%
bes[bes.Author=='Francis Chan']
# Out:
#                                             Name        Author  User Rating  \
# 3    Crazy Love: Overwhelmed by a Relentless God  Francis Chan          4.7
# 55   Crazy Love: Overwhelmed by a Relentless God  Francis Chan          4.7
# 105  Crazy Love: Overwhelmed by a Relentless God  Francis Chan          4.7
#
#      Reviews  Price  Year        Genre
# 3       1542     14  2009  Non Fiction
# 55      1542     14  2010  Non Fiction
# 105     1542     14  2011  Non Fiction

# %%
bes[bes["Author"]=='Francis Chan']
# Out:
#                                             Name        Author  User Rating  \
# 3    Crazy Love: Overwhelmed by a Relentless God  Francis Chan          4.7
# 55   Crazy Love: Overwhelmed by a Relentless God  Francis Chan          4.7
# 105  Crazy Love: Overwhelmed by a Relentless God  Francis Chan          4.7
#
#      Reviews  Price  Year        Genre
# 3       1542     14  2009  Non Fiction
# 55      1542     14  2010  Non Fiction
# 105     1542     14  2011  Non Fiction

# %%
bes[bes["User Rating"]> 4.6]
# Out:
#                                                   Name                 Author  \
# 3          Crazy Love: Overwhelmed by a Relentless God           Francis Chan
# 5        Diary of a Wimpy Kid: The Last Straw (Book 3)            Jeff Kinney
# 7    Dog Days (Diary of a Wimpy Kid, Book 4) (Volum...            Jeff Kinney
# 10                            Eclipse (Twilight Sagas)        Stephenie Meyer
# 11                                  Eclipse (Twilight)        Stephenie Meyer
# ..                                                 ...                    ...
# 693                        The Very Hungry Caterpillar             Eric Carle
# 695                   The Wonderful Things You Will Be  Emily Winfield Martin
# 696                                 Ugly Love: A Novel         Colleen Hoover
# 698               What to Expect When You're Expecting          Heidi Murkoff
# 699                            Where the Crawdads Sing            Delia Owens
#
# ...

# %%
bes[bes["Price"]<10]
# Out:
#                                                   Name                 Author  \
# 1    Arguing with Idiots: How to Stop Small Minds a...             Glenn Beck
# 4    Dead And Gone: A Sookie Stackhouse Novel (Sook...       Charlaine Harris
# 6    Divine Soul Mind Body Healing and Transmission...           Zhi Gang Sha
# 8    Eat This Not That! Supermarket Survival Guide:...        David Zinczenko
# 10                            Eclipse (Twilight Sagas)        Stephenie Meyer
# ..                                                 ...                    ...
# 679  The Alchemist, 25th Anniversary: A Fable About...           Paulo Coelho
# 683  The Four Agreements: A Practical Guide to Pers...        Don Miguel Ruiz
# 691         The Seven Husbands of Evelyn Hugo: A Novel    Taylor Jenkins Reid
# 693                        The Very Hungry Caterpillar             Eric Carle
# 695                   The Wonderful Things You Will Be  Emily Winfield Martin
#
# ...

# %%
bes[bes["Price"].between(50,60)].value_counts()
# Out:
# Name                                                         Author              User Rating  Reviews  Price  Year  Genre
# Hamilton: The Revolution                                     Lin-Manuel Miranda  4.9          5867     54     2016  Non Fiction    1
# Harry Potter Paperback Box Set (Books 1-7)                   J. K. Rowling       4.8          13471    52     2016  Fiction        1
# The Book of Basketball: The NBA According to The Sports Guy  Bill Simmons        4.7          858      53     2009  Non Fiction    1
# Name: count, dtype: int64

# %%
bes[(bes["Author"]=="Eric Carle")| (bes["Author"]=="Emily Winfield Martin")]
# Out:
#                                  Name                 Author  User Rating  \
# 245       The Very Hungry Caterpillar             Eric Carle          4.9
# 292       The Very Hungry Caterpillar             Eric Carle          4.9
# 343       The Very Hungry Caterpillar             Eric Carle          4.9
# 391       The Very Hungry Caterpillar             Eric Carle          4.9
# 393  The Wonderful Things You Will Be  Emily Winfield Martin          4.9
# 441       The Very Hungry Caterpillar             Eric Carle          4.9
# 443  The Wonderful Things You Will Be  Emily Winfield Martin          4.9
# 495       The Very Hungry Caterpillar             Eric Carle          4.9
# 496  The Wonderful Things You Will Be  Emily Winfield Martin          4.9
# 540       The Very Hungry Caterpillar             Eric Carle          4.9
# 541  The Wonderful Things You Will Be  Emily Winfield Martin          4.9
# 592       The Very Hungry Caterpillar             Eric Carle          4.9
# ...

# %%
bes[bes["Author"].isin(["Eric Carle","Emily Winfield Martin"])]
# Out:
#                                  Name                 Author  User Rating  \
# 245       The Very Hungry Caterpillar             Eric Carle          4.9
# 292       The Very Hungry Caterpillar             Eric Carle          4.9
# 343       The Very Hungry Caterpillar             Eric Carle          4.9
# 391       The Very Hungry Caterpillar             Eric Carle          4.9
# 393  The Wonderful Things You Will Be  Emily Winfield Martin          4.9
# 441       The Very Hungry Caterpillar             Eric Carle          4.9
# 443  The Wonderful Things You Will Be  Emily Winfield Martin          4.9
# 495       The Very Hungry Caterpillar             Eric Carle          4.9
# 496  The Wonderful Things You Will Be  Emily Winfield Martin          4.9
# 540       The Very Hungry Caterpillar             Eric Carle          4.9
# 541  The Wonderful Things You Will Be  Emily Winfield Martin          4.9
# 592       The Very Hungry Caterpillar             Eric Carle          4.9
# ...

# %%
bes[(bes["Genre"]=="Non Fiction")& (bes["User Rating"]==4.9)]
# Out:
#                                                   Name              Author  \
# 115  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 162  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 217  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 264  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 320                       Humans of New York : Stories     Brandon Stanton
# 321  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 364                           Hamilton: The Revolution  Lin-Manuel Miranda
# 371  Jesus Calling: Enjoying Peace in His Presence ...         Sarah Young
# 388                                 The Magnolia Story         Chip Gaines
# 420                        Obama: An Intimate Portrait          Pete Souza
# 544                             Unfreedom of the Press       Mark R. Levin
# ...

# %%
bes[(bes["Genre"]=="Fiction")& (bes["User Rating"]==4.9)].Price.nsmalest()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_17856\3361740229.py in ?()
# ----> 1 bes[(bes["Genre"]=="Fiction")& (bes["User Rating"]==4.9)].Price.nsmalest()
#
# ~\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    5985             and name not in self._accessors
#    5986             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5987         ):
#    5988             return self[name]
# -> 5989         return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'nsmalest'

# %%
bes[(bes["Genre"]=="Fiction")].nsmallest(1,["User Rating"])
# Out:
#                    Name        Author  User Rating  Reviews  Price  Year  \
# 178  The Casual Vacancy  J.K. Rowling          3.3     9372     12  2012
#
#        Genre
# 178  Fiction

# %%
bes[(bes["Genre"]=="Fiction") & (bes["Year"]==2012)].nlargest(5,["Reviews"])
# Out:
#                                                   Name           Author  \
# 158                                          Gone Girl    Gillian Flynn
# 179                             The Fault in Our Stars       John Green
# 155  Fifty Shades of Grey: Book One of the Fifty Sh...        E L James
# 183                          The Hunger Games (Book 1)  Suzanne Collins
# 165                      Mockingjay (The Hunger Games)  Suzanne Collins
#
#      User Rating  Reviews  Price  Year    Genre
# 158          4.0    57271     10  2012  Fiction
# 179          4.7    50482     13  2012  Fiction
# 155          3.8    47265     14  2012  Fiction
# 183          4.7    32122      8  2012  Fiction
# 165          4.5    26741      8  2012  Fiction

# %%
bes[(bes["User Rating"]<4.5)].Author.value_counts(5).plot(kind="bar")
# Out:
# <Axes: xlabel='Author'>

# %%
bes[bes.Genre=="Fiction"].sort_values("User Rating").head(1)
# Out:
#                    Name        Author  User Rating  Reviews  Price  Year  \
# 178  The Casual Vacancy  J.K. Rowling          3.3     9372     12  2012
#
#        Genre
# 178  Fiction

# %%
bes[bes["User Rating"]<4.5].value_counts("Author").head().plot()
# Out:
# <Axes: xlabel='Author'>

# %%
bes[(bes["User Rating"]<4.5)].Author.value_counts(5)
# Out:
# Author
# Gallup               0.082569
# The College Board    0.055046
# E L James            0.036697
# John Grisham         0.027523
# Dan Brown            0.027523
#                        ...
# Mark Hyman M.D.      0.009174
# Elizabeth Strout     0.009174
# Cheryl Strayed       0.009174
# Veronica Roth        0.009174
# Stephen Perrine      0.009174
# Name: proportion, Length: 68, dtype: float64

# %%
bes[(bes["User Rating"]<4.5)].Author.value_counts().head().plot()
# Out:
# <Axes: xlabel='Author'>

# %%
import pandas as pd
jo=pd.read_csv('downloads/JoeBidenTweets.csv')

# %%
jo
# Out:
#                        id         timestamp  \
# 0               361388562  2007-10-24 22:45
# 1               543984392  2007-12-29 15:35
# 2      189287227321356289  2012-04-09 09:42
# 3      189287350034104320  2012-04-09 09:43
# 4      189339650610036736  2012-04-09 13:11
# ...                   ...               ...
# 6059  1322865972819251200  2020-11-01 11:40
# 6060  1322871257902145536  2020-11-01 12:01
# 6061  1322876039144636417  2020-11-01 12:20
# 6062  1322881072363917312  2020-11-01 12:40
# 6063  1322886357535150081  2020-11-01 13:01
#
#                                                     url  \
# 0         https://twitter.com/JoeBiden/status/361388562
# 1         https://twitter.com/JoeBiden/status/543984392
# 2     https://twitter.com/JoeBiden/status/1892872273...
# 3     https://twitter.com/JoeBiden/status/1892873500...
# 4     https://twitter.com/JoeBiden/status/1893396506...
# ...                                                 ...
# ...

# %%
jo.set_index("id",inplace=True)

# %%
jo.drop(columns=["url"])
# Out:
#                        id         timestamp  \
# 0               361388562  2007-10-24 22:45
# 1               543984392  2007-12-29 15:35
# 2      189287227321356289  2012-04-09 09:42
# 3      189287350034104320  2012-04-09 09:43
# 4      189339650610036736  2012-04-09 13:11
# ...                   ...               ...
# 6059  1322865972819251200  2020-11-01 11:40
# 6060  1322871257902145536  2020-11-01 12:01
# 6061  1322876039144636417  2020-11-01 12:20
# 6062  1322881072363917312  2020-11-01 12:40
# 6063  1322886357535150081  2020-11-01 13:01
#
#                                                   tweet  replies  retweets  \
# 0     Tune in 11:30 ET tomorrow for a live webcast o...       19         5
# 1     Iowans, there's a good chance there's a Biden ...       13        16
# 2     We're excited to announce that @JoeBiden is be...       21        82
# 3     Campaign staff will run this account to keep y...      144        76
# ...

# %%
jo
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# ...

# %%
jo.drop(columns=["url"])
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                  tweet  \
# id
# 361388562            Tune in 11:30 ET tomorrow for a live webcast o...
# 543984392            Iowans, there's a good chance there's a Biden ...
# 189287227321356289   We're excited to announce that @JoeBiden is be...
# 189287350034104320   Campaign staff will run this account to keep y...
# 189339650610036736   News for you this morning: VP Biden will speak...
# ...

# %%
jo.drop(labels=543984392)
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# 189343279140184065   2012-04-09 13:25
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# 189343279140184065   https://twitter.com/JoeBiden/status/1893432791...
# ...

# %%
jo
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# ...

# %%
jo["user"]="jo biden"

# %%
jo
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# ...

# %%
jo["ratio"]=jo["replies"]/jo["retweets"]

# %%
jo
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# ...

# %%
jo["ratio"].nlargest(10)
# Out:
# id
# 232971730119950338     10.000000
# 1200882191875465216     8.239745
# 1150774078233387008     7.745342
# 1186989582182694922     6.194940
# 1189327302733238272     5.852217
# 1181979945599455232     5.822957
# 1141149986505330693     5.755224
# 1186830433985748993     5.545109
# 1172309499048165376     4.933798
# 1152313660787908610     4.812950
# Name: ratio, dtype: float64

# %%
jo.nlargest(10,["ratio"])
# Out:
#                             timestamp  \
# id
# 232971730119950338   2012-08-07 22:49
# 1200882191875465216  2019-11-30 21:00
# 1150774078233387008  2019-07-15 14:28
# 1186989582182694922  2019-10-23 12:55
# 1189327302733238272  2019-10-29 23:45
# 1181979945599455232  2019-10-09 17:09
# 1141149986505330693  2019-06-19 01:05
# 1186830433985748993  2019-10-23 02:23
# 1172309499048165376  2019-09-13 00:42
# 1152313660787908610  2019-07-19 20:26
#
#                                                                    url  \
# id
# 232971730119950338   https://twitter.com/JoeBiden/status/2329717301...
# 1200882191875465216  https://twitter.com/JoeBiden/status/1200882191...
# 1150774078233387008  https://twitter.com/JoeBiden/status/1150774078...
# 1186989582182694922  https://twitter.com/JoeBiden/status/1186989582...
# 1189327302733238272  https://twitter.com/JoeBiden/status/1189327302...
# 1181979945599455232  https://twitter.com/JoeBiden/status/1181979945...
# ...

# %%
jo["ratio"].sort_values(ascending=False).head(10)
# Out:
# id
# 232971730119950338     10.000000
# 1200882191875465216     8.239745
# 1150774078233387008     7.745342
# 1186989582182694922     6.194940
# 1189327302733238272     5.852217
# 1181979945599455232     5.822957
# 1141149986505330693     5.755224
# 1186830433985748993     5.545109
# 1172309499048165376     4.933798
# 1152313660787908610     4.812950
# Name: ratio, dtype: float64

# %%
jo.sort_values(["ratio"],ascending=False).head(10)
# Out:
#                             timestamp  \
# id
# 232971730119950338   2012-08-07 22:49
# 1200882191875465216  2019-11-30 21:00
# 1150774078233387008  2019-07-15 14:28
# 1186989582182694922  2019-10-23 12:55
# 1189327302733238272  2019-10-29 23:45
# 1181979945599455232  2019-10-09 17:09
# 1141149986505330693  2019-06-19 01:05
# 1186830433985748993  2019-10-23 02:23
# 1172309499048165376  2019-09-13 00:42
# 1152313660787908610  2019-07-19 20:26
#
#                                                                    url  \
# id
# 232971730119950338   https://twitter.com/JoeBiden/status/2329717301...
# 1200882191875465216  https://twitter.com/JoeBiden/status/1200882191...
# 1150774078233387008  https://twitter.com/JoeBiden/status/1150774078...
# 1186989582182694922  https://twitter.com/JoeBiden/status/1186989582...
# 1189327302733238272  https://twitter.com/JoeBiden/status/1189327302...
# 1181979945599455232  https://twitter.com/JoeBiden/status/1181979945...
# ...

# %%
jo["interaction"]=jo["replies"]+jo["retweets"]+jo["quotes"]+jo["likes"]

# %%
jo
# Out:
#                             timestamp  \
# id
# 361388562            2007-10-24 22:45
# 543984392            2007-12-29 15:35
# 189287227321356289   2012-04-09 09:42
# 189287350034104320   2012-04-09 09:43
# 189339650610036736   2012-04-09 13:11
# ...                               ...
# 1322865972819251200  2020-11-01 11:40
# 1322871257902145536  2020-11-01 12:01
# 1322876039144636417  2020-11-01 12:20
# 1322881072363917312  2020-11-01 12:40
# 1322886357535150081  2020-11-01 13:01
#
#                                                                    url  \
# id
# 361388562                https://twitter.com/JoeBiden/status/361388562
# 543984392                https://twitter.com/JoeBiden/status/543984392
# 189287227321356289   https://twitter.com/JoeBiden/status/1892872273...
# 189287350034104320   https://twitter.com/JoeBiden/status/1892873500...
# 189339650610036736   https://twitter.com/JoeBiden/status/1893396506...
# ...

# %%
jo["tweet"].sort_values(["interaction"],ascending=False).head(10)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[29], line 1
# ----> 1 jo["tweet"].sort_values(["interaction"],ascending=False).head(10)
#
# TypeError: Series.sort_values() takes 1 positional argument but 2 positional arguments (and 1 keyword-only argument) were given

# %%
jo.sort_values(["interaction"],ascending=False)[["tweet","interaction"]].head(10)
# Out:
#                                                                  tweet  \
# id
# 1311120831032909825  Donald Trump is the worst president we've ever...
# 1253751812194070529  I can’t believe I have to say this, but please...
# 1317978773707345920  Wear a mask. Wash your hands. Vote out Donald ...
# 1318170176660135936                     ...yes https://t.co/RzZ3j3zoAL
# 1312460408192724992  One month until Election Day. Let’s do this, A...
# 1314034535890378752     .@KamalaHarris, you made us all proud tonight.
# 1314031047013732352  Pitch in $5 to help this campaign fly. https:/...
# 1307491919384260609  I’m Joe Biden and I approve this message. http...
# 1293280411150217219  I have the great honor to announce that I’ve p...
# 1312010736604979201  Jill and I send our thoughts to President Trum...
#
#                      interaction
# id
# 1311120831032909825      2293793
# 1253751812194070529      2073072
# 1317978773707345920      1612157
# 1318170176660135936      1494296
# ...

# %%
import pandas as pd
net=pd.read_csv("downloads/Netflix Userbase.csv")

# %%
net
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
net.set_index("User ID",inplace=True)

# %%
net
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 1                   Basic               10  15-01-22          10-06-23
# 2                 Premium               15  05-09-21          22-06-23
# 3                Standard               12  28-02-23          27-06-23
# 4                Standard               12  10-07-22          26-06-23
# 5                   Basic               10  01-05-23          28-06-23
# ...                   ...              ...       ...               ...
# 2496              Premium               14  25-07-22          12-07-23
# 2497                Basic               15  04-08-22          14-07-23
# 2498             Standard               12  09-08-22          15-07-23
# 2499             Standard               13  12-08-22          12-07-23
# 2500                Basic               15  13-08-22          12-07-23
#
#                 Country  Age  Gender      Device Plan Duration
# User ID
# ...

# %%
net.loc[[2500]]
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 2500                Basic               15  13-08-22          12-07-23
#
#                Country  Age  Gender    Device Plan Duration
# User ID
# 2500     United States   35  Female  Smart TV       1 Month

# %%
net.loc[[2500],["Country"]]="America"

# %%
net.loc[[2500]]
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 2500                Basic               15  13-08-22          12-07-23
#
#          Country  Age  Gender    Device Plan Duration
# User ID
# 2500     America   35  Female  Smart TV       1 Month

# %%
net.loc[[2500,2499],["Country"]]="America"

# %%
net.loc[[2500,2499]]
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 2500                Basic               15  13-08-22          12-07-23
# 2499             Standard               13  12-08-22          12-07-23
#
#          Country  Age  Gender    Device Plan Duration
# User ID
# 2500     America   35  Female  Smart TV       1 Month
# 2499     America   48  Female    Tablet       1 Month

# %%
map={"Country":"Country1"}
net.rename(columns=map, inplace=True)

# %%
net
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 1                   Basic               10  15-01-22          10-06-23
# 2                 Premium               15  05-09-21          22-06-23
# 3                Standard               12  28-02-23          27-06-23
# 4                Standard               12  10-07-22          26-06-23
# 5                   Basic               10  01-05-23          28-06-23
# ...                   ...              ...       ...               ...
# 2496              Premium               14  25-07-22          12-07-23
# 2497                Basic               15  04-08-22          14-07-23
# 2498             Standard               12  09-08-22          15-07-23
# 2499             Standard               13  12-08-22          12-07-23
# 2500                Basic               15  13-08-22          12-07-23
#
#                Country1  Age  Gender      Device Plan Duration
# User ID
# ...

# %%
con=net[net["Country1"]] =="Canada"
age=net[net["Age"]] ==27
jo=net[net["Join Date"]] =='19-11-22'
net.loc[age & con & jo ,["User ID"]]=1111
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[23], line 1
# ----> 1 con=net[net["Country1"]] =="Canada"
#       2 age=net[net["Age"]] ==27
#       3 jo=net[net["Join Date"]] =='19-11-22'
#
# File ~\anaconda3\Lib\site-packages\pandas\core\frame.py:3767, in DataFrame.__getitem__(self, key)
#    3765     if is_iterator(key):
#    3766         key = list(key)
# -> 3767     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3769 # take() does not accept boolean indexers
#    3770 if getattr(indexer, "dtype", None) == bool:
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:5877, in Index._get_indexer_strict(self, key, axis_name)
#    5874 else:
#    5875     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5877 self._raise_if_missing(keyarr, indexer, axis_name)
#    5879 keyarr = self.take(indexer)
# ...

# %%
net["Country1"] =="Canada"
# Out:
# User ID
# 1       False
# 2        True
# 3       False
# 4       False
# 5       False
#         ...
# 2496    False
# 2497    False
# 2498    False
# 2499    False
# 2500    False
# Name: Country1, Length: 2500, dtype: bool

# %%
con=net[net["Country1"] =="Canada"]
con
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 2                 Premium               15  05-09-21          22-06-23
# 12                Premium               15  23-03-23          28-06-23
# 22                  Basic               10  22-07-22          28-06-23
# 32                  Basic               10  07-07-22          28-06-23
# 42                  Basic               10  15-06-22          28-06-23
# ...                   ...              ...       ...               ...
# 2457                Basic               11  12-11-22          10-07-23
# 2469              Premium               12  24-10-22          11-07-23
# 2472                Basic               14  29-09-22          14-07-23
# 2484             Standard               11  29-07-22          13-07-23
# 2487              Premium               11  25-07-22          12-07-23
#
#         Country1  Age  Gender      Device Plan Duration
# User ID
# ...

# %%
age=net[net["Age"] ==27]
age
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 14                  Basic               10  01-08-22          26-06-23
# 39                Premium               15  28-12-22          23-06-23
# 59                Premium               15  03-12-22          23-06-23
# 71                  Basic               10  26-01-22          20-06-23
# 108              Standard               12  24-05-22          25-06-23
# ...                   ...              ...       ...               ...
# 2350                Basic               12  14-07-22          13-07-23
# 2397                Basic               15  29-10-22          11-07-23
# 2412              Premium               12  01-08-22          13-07-23
# 2447                Basic               14  21-10-22          12-07-23
# 2472                Basic               14  29-09-22          14-07-23
#
#               Country1  Age  Gender      Device Plan Duration
# User ID
# ...

# %%
jo=net[net["Join Date"] =='19-11-22']
jo
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 432                 Basic               12  19-11-22          30-06-23
# 642                 Basic               11  19-11-22          01-07-23
#
#         Country1  Age  Gender    Device Plan Duration
# User ID
# 432       Canada   46  Female  Smart TV       1 Month
# 642       Canada   27    Male    Laptop       1 Month

# %%
con=net["Country1"] =="Canada"
jo=net["Join Date"] =='19-11-22'
age=net["Age"] ==27
net[age & con & jo]
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 642                 Basic               11  19-11-22          01-07-23
#
#         Country1  Age Gender  Device Plan Duration
# User ID
# 642       Canada   27   Male  Laptop       1 Month

# %%
net[age & con & jo].rename(index={642:1111})
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 1111                Basic               11  19-11-22          01-07-23
#
#         Country1  Age Gender  Device Plan Duration
# User ID
# 1111      Canada   27   Male  Laptop       1 Month

# %%
net
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 1                   Basic               10  15-01-22          10-06-23
# 2                 Premium               15  05-09-21          22-06-23
# 3                Standard               12  28-02-23          27-06-23
# 4                Standard               12  10-07-22          26-06-23
# 5                   Basic               10  01-05-23          28-06-23
# ...                   ...              ...       ...               ...
# 2496              Premium               14  25-07-22          12-07-23
# 2497                Basic               15  04-08-22          14-07-23
# 2498             Standard               12  09-08-22          15-07-23
# 2499             Standard               13  12-08-22          12-07-23
# 2500                Basic               15  13-08-22          12-07-23
#
#                Country1  Age  Gender      Device Plan Duration
# User ID
# ...

# %%
change={"Canada":"xx","Spain":"xx"}
net.rename(columns=change)
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 1                   Basic               10  15-01-22          10-06-23
# 2                 Premium               15  05-09-21          22-06-23
# 3                Standard               12  28-02-23          27-06-23
# 4                Standard               12  10-07-22          26-06-23
# 5                   Basic               10  01-05-23          28-06-23
# ...                   ...              ...       ...               ...
# 2496              Premium               14  25-07-22          12-07-23
# 2497                Basic               15  04-08-22          14-07-23
# 2498             Standard               12  09-08-22          15-07-23
# 2499             Standard               13  12-08-22          12-07-23
# 2500                Basic               15  13-08-22          12-07-23
#
#                Country1  Age  Gender      Device Plan Duration
# User ID
# ...

# %%
con=net["Country1"]=="Canada"
asa=net["Country1"]=="Spain"
net.loc[con | asa ,["Country1"]]="xxx"

# %%
net
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 1                   Basic               10  15-01-22          10-06-23
# 2                 Premium               15  05-09-21          22-06-23
# 3                Standard               12  28-02-23          27-06-23
# 4                Standard               12  10-07-22          26-06-23
# 5                   Basic               10  01-05-23          28-06-23
# ...                   ...              ...       ...               ...
# 2496              Premium               14  25-07-22          12-07-23
# 2497                Basic               15  04-08-22          14-07-23
# 2498             Standard               12  09-08-22          15-07-23
# 2499             Standard               13  12-08-22          12-07-23
# 2500                Basic               15  13-08-22          12-07-23
#
#         Country1  Age  Gender      Device Plan Duration
# User ID
# ...

# %%
net.Country1.value_counts()
# Out:
# Country1
# xxx    2500
# Name: count, dtype: int64

# %%
con=net["Country1"]=="Canada"
con
# Out:
# User ID
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 2496    False
# 2497    False
# 2498    False
# 2499    False
# 2500    False
# Name: Country1, Length: 2500, dtype: bool

# %%
net.loc[con | asa]
# Out:
#         Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# User ID
# 1                   Basic               10  15-01-22          10-06-23
# 2                 Premium               15  05-09-21          22-06-23
# 3                Standard               12  28-02-23          27-06-23
# 4                Standard               12  10-07-22          26-06-23
# 5                   Basic               10  01-05-23          28-06-23
# ...                   ...              ...       ...               ...
# 2496              Premium               14  25-07-22          12-07-23
# 2497                Basic               15  04-08-22          14-07-23
# 2498             Standard               12  09-08-22          15-07-23
# 2499             Standard               13  12-08-22          12-07-23
# 2500                Basic               15  13-08-22          12-07-23
#
#         Country1  Age  Gender      Device Plan Duration
# User ID
# ...

# %%
con=net["Country1"]=="Canada"
con
# Out:
# User ID
# 1       False
# 2       False
# 3       False
# 4       False
# 5       False
#         ...
# 2496    False
# 2497    False
# 2498    False
# 2499    False
# 2500    False
# Name: Country1, Length: 2500, dtype: bool

# %%
import pandas as pd
net=pd.read_csv('downloads/Netflix Userbase.csv')
net
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
con=net["Country"]=="Canada"
asa=net["Country"]=="Spain"
net.loc[con | asa ,["Country"]]="xxx"

# %%
net
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
cont={"Germany","xxx"}
m=net["Country"].isin(cont)
net.loc[net["Country"].isin(cont) ,["Country"]]="xxx"

# %%
net
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0           1             Basic               10  15-01-22          10-06-23
# 1           2           Premium               15  05-09-21          22-06-23
# 2           3          Standard               12  28-02-23          27-06-23
# 3           4          Standard               12  10-07-22          26-06-23
# 4           5             Basic               10  01-05-23          28-06-23
# ...       ...               ...              ...       ...               ...
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
# ...

# %%
cont={"Germany","xxx"}
m=net["Country"].isin(cont)
net.loc[net["Country"].isin(cont)]="AAA"

# %%
net
# Out:
#      User ID Subscription Type Monthly Revenue Join Date Last Payment Date  \
# 0          1             Basic              10  15-01-22          10-06-23
# 1        AAA               AAA             AAA       AAA               AAA
# 2          3          Standard              12  28-02-23          27-06-23
# 3          4          Standard              12  10-07-22          26-06-23
# 4        AAA               AAA             AAA       AAA               AAA
# ...      ...               ...             ...       ...               ...
# 2495     AAA               AAA             AAA       AAA               AAA
# 2496     AAA               AAA             AAA       AAA               AAA
# 2497    2498          Standard              12  09-08-22          15-07-23
# 2498     AAA               AAA             AAA       AAA               AAA
# 2499    2500             Basic              15  13-08-22          12-07-23
#
#              Country  Age  Gender      Device Plan Duration
# ...

# %%
net["Gender"].value_counts()
# Out:
# Gender
# AAA       951
# Male      776
# Female    773
# Name: count, dtype: int64

# %%
net["is_fab"]="False"
net
# Out:
#      User ID Subscription Type Monthly Revenue Join Date Last Payment Date  \
# 0          1             Basic              10  15-01-22          10-06-23
# 1        AAA               AAA             AAA       AAA               AAA
# 2          3          Standard              12  28-02-23          27-06-23
# 3          4          Standard              12  10-07-22          26-06-23
# 4        AAA               AAA             AAA       AAA               AAA
# ...      ...               ...             ...       ...               ...
# 2495     AAA               AAA             AAA       AAA               AAA
# 2496     AAA               AAA             AAA       AAA               AAA
# 2497    2498          Standard              12  09-08-22          15-07-23
# 2498     AAA               AAA             AAA       AAA               AAA
# 2499    2500             Basic              15  13-08-22          12-07-23
#
#              Country  Age  Gender      Device Plan Duration is_fab
# ...

# %%
fav={28,42,51}
net.loc[net["Age"].isin(fav) ,["is_fab"]]="True"

# %%
net
# Out:
#      User ID Subscription Type Monthly Revenue Join Date Last Payment Date  \
# 0          1             Basic              10  15-01-22          10-06-23
# 1        AAA               AAA             AAA       AAA               AAA
# 2          3          Standard              12  28-02-23          27-06-23
# 3          4          Standard              12  10-07-22          26-06-23
# 4        AAA               AAA             AAA       AAA               AAA
# ...      ...               ...             ...       ...               ...
# 2495     AAA               AAA             AAA       AAA               AAA
# 2496     AAA               AAA             AAA       AAA               AAA
# 2497    2498          Standard              12  09-08-22          15-07-23
# 2498     AAA               AAA             AAA       AAA               AAA
# 2499    2500             Basic              15  13-08-22          12-07-23
#
#              Country  Age  Gender      Device Plan Duration is_fab
# ...
